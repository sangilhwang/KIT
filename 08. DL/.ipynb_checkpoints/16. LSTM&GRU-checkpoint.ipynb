# %% [markdown]
# # LSTM(Long Short-Term Memory) 구조
#
# <img src = "./image/rnn_lstm.jpg">

# %% [markdown]
# - 단기 기억을 오래 기억하기 위해 고안되었음

# %% [markdown]
# <img src = "./image/lstm.png">

# %% [markdown]
# - 은닉 상태를 만드는 방법
#     - output gate layer(출력 게이트)
#         1. 입력과 이전 타임스텝의 은닉 상태를 가중치에 곱한 후 활성화 함수를 통과시켜 다음 은닉상태를 만듦
#             - 이 때 기본 순환층과는 달리 시그모이드 활성화 함수를 사용
#         2. tanh 활성화 함수를 통과한 값과 곱해져서 은닉 상태를 만듦
#
# - LSTM 은 순환 되는 상태가 2개
#     - 은닉 상태
#     - 셀 상태(cell state)
#         - 다음 층으로 전달되지 않고 LSTM 셀에서 순환만 되는 값
#
# - 셀 상태를 계산하는 과정
#     - forget gate layer(삭제 게이트) [왼쪽 게이트]
#         - 정보를 제거하는 역할
#         1. 입력과 은닉 상태를 또 다른 가중치에 곱한 다음 시그모이드 함수를 통과
#         2. 이전 타임스텝의 셀 상태와 곱하여 새로운 셀 상태를 만듦
#             - 이 셀 상태가 오른쪽에서 tanh 함수를 통과하여 새로운 은닉 상태를 만드는 데 기여
#
#     - input gate layer(입력 게이트) [가운데 2개의 게이트]
#         - 새로운 정보를 셀 상태에 추가
#         1. 입력과 은닉 상태를 각기 다른 가중치에 곱함
#         2. 하나는 시그모이드 함수, 하나는 tanh 함수를 통과
#         3. 두 결과를 곱함
#         4. 이전 셀 상태와 더함

# %% [markdown]
# ## 데이터 준비

# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow import keras
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
# 데이터 로드
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words = 500)

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2, random_state = 12)

# %%
# 패딩
train_seq = pad_sequences(x_train, maxlen = 100)
val_seq = pad_sequences(x_val, maxlen = 100)

# %%
model = keras.Sequential()
model.add(keras.layers.Embedding(500, 32, input_shape = (100,)))
model.add(keras.layers.LSTM(8))
model.add(keras.layers.Dense(1, activation = "sigmoid"))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)              │ (None, 100, 32)             │          16,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 8)                   │           1,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 17,321 (67.66 KB)
#  Trainable params: 17,321 (67.66 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# - LSTM 셀의 파라미터 개수
#     - ((유닛 수 * 유닛 수) + (입력값의 수 * 유닛 수) + 유닛 수) * 4
#     - ((8 * 8) + (32 * 8) + 8) * 4

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate = 1e-4)
model.compile(optimizer = rmsprop, loss = "binary_crossentropy", metrics = ["accuracy"])
checkpoint_cb = keras.callbacks.ModelCheckpoint("./model/best-lstm-model.keras", save_best_only = True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience = 4, restore_best_weights = True)

# %%
history = model.fit(train_seq, y_train, epochs = 100, batch_size = 64,
                   validation_data = (val_seq, y_val), callbacks = [checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.4999 - loss: 0.6931 - val_accuracy: 0.5382 - val_loss: 0.6924
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.5499 - loss: 0.6919 - val_accuracy: 0.5676 - val_loss: 0.6909
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.5874 - loss: 0.6902 - val_accuracy: 0.5878 - val_loss: 0.6880
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.5960 - loss: 0.6866 - val_accuracy: 0.6202 - val_loss: 0.6806
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.6508 - loss: 0.6752 - val_accuracy: 0.7056 - val_loss: 0.6470
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.7142 - loss: 0.6302 - val_accuracy: 0.7198 - val_loss: 0.6010
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7281 - loss: 0.5922 - val_accuracy: 0.7340 - val_loss: 0.5807
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7498 - loss: 0.5696 - val_accuracy: 0.7506 - val_loss: 0.5621
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7619 - loss: 0.5495 - val_accuracy: 0.7564 - val_loss: 0.5421
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7741 - loss: 0.5307 - val_accuracy: 0.7658 - val_loss: 0.5261
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7854 - loss: 0.5108 - val_accuracy: 0.7746 - val_loss: 0.5119
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7876 - loss: 0.4992 - val_accuracy: 0.7824 - val_loss: 0.4946
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7959 - loss: 0.4820 - val_accuracy: 0.7810 - val_loss: 0.4849
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8018 - loss: 0.4708 - val_accuracy: 0.7906 - val_loss: 0.4754
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8031 - loss: 0.4616 - val_accuracy: 0.7896 - val_loss: 0.4702
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8052 - loss: 0.4528 - val_accuracy: 0.7910 - val_loss: 0.4641
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8067 - loss: 0.4476 - val_accuracy: 0.7930 - val_loss: 0.4623
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8062 - loss: 0.4430 - val_accuracy: 0.7954 - val_loss: 0.4559
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8089 - loss: 0.4405 - val_accuracy: 0.7944 - val_loss: 0.4563
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8095 - loss: 0.4351 - val_accuracy: 0.7892 - val_loss: 0.4578
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8097 - loss: 0.4328 - val_accuracy: 0.7984 - val_loss: 0.4493
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8137 - loss: 0.4228 - val_accuracy: 0.7954 - val_loss: 0.4510
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8111 - loss: 0.4232 - val_accuracy: 0.7962 - val_loss: 0.4470
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.8112 - loss: 0.4297 - val_accuracy: 0.7932 - val_loss: 0.4539
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8118 - loss: 0.4247 - val_accuracy: 0.8010 - val_loss: 0.4442
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8230 - loss: 0.4150 - val_accuracy: 0.7960 - val_loss: 0.4445
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8139 - loss: 0.4237 - val_accuracy: 0.7918 - val_loss: 0.4492
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8108 - loss: 0.4229 - val_accuracy: 0.7800 - val_loss: 0.4665
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8141 - loss: 0.4193 - val_accuracy: 0.7932 - val_loss: 0.4473

# %%
plt.figure()

plt.plot(history.history["loss"], label = "loss")
plt.plot(history.history["accuracy"], label = "acc")
plt.plot(history.history["val_loss"], label = "val_loss")
plt.plot(history.history["val_accuracy"], label = "val_acc")

plt.legend(("train_loss", "train_acc", "val_loss", "val_acc"))
plt.xlabel("epoch")
plt.show()

# %% [markdown]
# # 순환층에 드롭아웃 적용
#
# - 순환층은 자체적으로 드롭아웃 기능을 제공
#     - SimpleRNN과 LSTM 클래스 모두 dropout 매개변수와 recurrent_dropout 매개변수를 가지고 있음
#         - dropout : 셀의 입력에 드롭아웃을 적용
#         - recurrent_dropout : 순환되는 은닉 상태에 드롭아웃을 적용
#             - 버전에 따라 recurrent_dropout이 GPU를 사용하지 못하는 경우가 있음

# %%
model2 = keras.Sequential()
model2.add(keras.layers.Embedding(500, 32, input_shape = (100,)))
model2.add(keras.layers.LSTM(8, dropout = 0.3))
model2.add(keras.layers.Dense(1, activation = "sigmoid"))

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate = 1e-4)
model2.compile(optimizer = rmsprop, loss = "binary_crossentropy", metrics = ["accuracy"])
checkpoint_cb = keras.callbacks.ModelCheckpoint("./model/best-dropout-model.keras", save_best_only = True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience = 4, restore_best_weights = True)

# %%
history = model2.fit(train_seq, y_train, epochs = 100, batch_size = 64,
            validation_data = (val_seq, y_val), callbacks = [checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.5253 - loss: 0.6924 - val_accuracy: 0.5724 - val_loss: 0.6901
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.5794 - loss: 0.6888 - val_accuracy: 0.6062 - val_loss: 0.6840
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.6239 - loss: 0.6797 - val_accuracy: 0.6906 - val_loss: 0.6538
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.6913 - loss: 0.6336 - val_accuracy: 0.7206 - val_loss: 0.5860
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7173 - loss: 0.5786 - val_accuracy: 0.7386 - val_loss: 0.5495
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7547 - loss: 0.5324 - val_accuracy: 0.7662 - val_loss: 0.5124
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7750 - loss: 0.5016 - val_accuracy: 0.7680 - val_loss: 0.4904
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7809 - loss: 0.4808 - val_accuracy: 0.7806 - val_loss: 0.4736
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7903 - loss: 0.4614 - val_accuracy: 0.7824 - val_loss: 0.4631
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7922 - loss: 0.4555 - val_accuracy: 0.7902 - val_loss: 0.4563
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7917 - loss: 0.4533 - val_accuracy: 0.7924 - val_loss: 0.4523
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7977 - loss: 0.4424 - val_accuracy: 0.7808 - val_loss: 0.4680
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8009 - loss: 0.4355 - val_accuracy: 0.7966 - val_loss: 0.4434
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7995 - loss: 0.4314 - val_accuracy: 0.7952 - val_loss: 0.4441
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8089 - loss: 0.4231 - val_accuracy: 0.7878 - val_loss: 0.4490
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8087 - loss: 0.4257 - val_accuracy: 0.7868 - val_loss: 0.4542
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8120 - loss: 0.4174 - val_accuracy: 0.7998 - val_loss: 0.4375
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8122 - loss: 0.4194 - val_accuracy: 0.7974 - val_loss: 0.4378
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8087 - loss: 0.4180 - val_accuracy: 0.7954 - val_loss: 0.4428
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8106 - loss: 0.4187 - val_accuracy: 0.7944 - val_loss: 0.4407
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8052 - loss: 0.4190 - val_accuracy: 0.8028 - val_loss: 0.4335
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8107 - loss: 0.4133 - val_accuracy: 0.8020 - val_loss: 0.4337
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8132 - loss: 0.4116 - val_accuracy: 0.8010 - val_loss: 0.4300
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8104 - loss: 0.4167 - val_accuracy: 0.8010 - val_loss: 0.4305
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8120 - loss: 0.4064 - val_accuracy: 0.8012 - val_loss: 0.4306
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8154 - loss: 0.4098 - val_accuracy: 0.8032 - val_loss: 0.4299
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8142 - loss: 0.4101 - val_accuracy: 0.8020 - val_loss: 0.4275
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8206 - loss: 0.3985 - val_accuracy: 0.8026 - val_loss: 0.4281
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8087 - loss: 0.4128 - val_accuracy: 0.7968 - val_loss: 0.4410
# Epoch 30/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8154 - loss: 0.4063 - val_accuracy: 0.8034 - val_loss: 0.4294
# Epoch 31/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8202 - loss: 0.3996 - val_accuracy: 0.7994 - val_loss: 0.4334

# %%
plt.figure()

plt.plot(history.history["loss"], label = "loss")
plt.plot(history.history["accuracy"], label = "acc")
plt.plot(history.history["val_loss"], label = "val_loss")
plt.plot(history.history["val_accuracy"], label = "val_acc")

plt.legend(("train_loss", "train_acc", "val_loss", "val_acc"))
plt.xlabel("epoch")
plt.show()

# %% [markdown]
# # 2개의 층을 연결
#
# - 순환층을 연결할 때의 주의점
#     - 순환 층의 은닉 상태는 샘플의 마지막 타임스텝에 대한 은닉 상태만 다음 층으로 전달
#         - 순환 층을 쌓게 되면 모든 순환층에 순차 데이터가 필요함
#         - 앞쪽의 순환층이 모든 타임스텝에 대한 은닉 상태를 출력해야함
#             - return_sequences 매개변수를 True로 지정

# %%
model3 = keras.Sequential()
model3.add(keras.layers.Embedding(500, 32, input_shape = (100,)))
model3.add(keras.layers.LSTM(8, dropout = 0.3, return_sequences = True))
model3.add(keras.layers.LSTM(8, dropout = 0.3))
model3.add(keras.layers.Dense(1, activation = "sigmoid"))

# %%
model3.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)              │ (None, 100, 32)             │          16,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 100, 8)              │           1,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_4 (LSTM)                        │ (None, 8)                   │             544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 17,865 (69.79 KB)
#  Trainable params: 17,865 (69.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# - 첫 번째 LSTM
#     - 모든 타임스텝(100개)의 은닉상태를 출력하기 때문에 출력의 크기가 (None, 100, 8)
# - 두 번째 LSTM
#     - 마지막 타임스텝의 은닉 상태만 출력하기 때문에 출력의 크기가 (None, 8)

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate = 1e-4)
model3.compile(optimizer = rmsprop, loss = "binary_crossentropy", metrics = ["accuracy"])
checkpoint_cb = keras.callbacks.ModelCheckpoint("./model/best-2rnn-model.keras", save_best_only = True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience = 4, restore_best_weights = True)

# %%
history = model3.fit(train_seq, y_train, epochs = 100, batch_size = 64,
            validation_data = (val_seq, y_val), callbacks = [checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 33ms/step - accuracy: 0.4920 - loss: 0.6932 - val_accuracy: 0.5134 - val_loss: 0.6927
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.5284 - loss: 0.6924 - val_accuracy: 0.5886 - val_loss: 0.6911
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.5812 - loss: 0.6897 - val_accuracy: 0.6546 - val_loss: 0.6813
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.6394 - loss: 0.6711 - val_accuracy: 0.6984 - val_loss: 0.6053
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.7012 - loss: 0.5929 - val_accuracy: 0.7366 - val_loss: 0.5494
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.7332 - loss: 0.5510 - val_accuracy: 0.7418 - val_loss: 0.5335
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.7528 - loss: 0.5254 - val_accuracy: 0.7606 - val_loss: 0.5105
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.7707 - loss: 0.5026 - val_accuracy: 0.7706 - val_loss: 0.4982
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.7758 - loss: 0.4915 - val_accuracy: 0.7658 - val_loss: 0.4956
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.7830 - loss: 0.4804 - val_accuracy: 0.7740 - val_loss: 0.4854
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.7825 - loss: 0.4819 - val_accuracy: 0.7784 - val_loss: 0.4799
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.7803 - loss: 0.4781 - val_accuracy: 0.7640 - val_loss: 0.4967
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.7821 - loss: 0.4762 - val_accuracy: 0.7826 - val_loss: 0.4703
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.7938 - loss: 0.4572 - val_accuracy: 0.7848 - val_loss: 0.4686
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.7916 - loss: 0.4601 - val_accuracy: 0.7868 - val_loss: 0.4639
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.7914 - loss: 0.4560 - val_accuracy: 0.7844 - val_loss: 0.4666
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.7944 - loss: 0.4533 - val_accuracy: 0.7884 - val_loss: 0.4593
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.7957 - loss: 0.4527 - val_accuracy: 0.7898 - val_loss: 0.4588
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.7965 - loss: 0.4503 - val_accuracy: 0.7852 - val_loss: 0.4643
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.8011 - loss: 0.4454 - val_accuracy: 0.7880 - val_loss: 0.4593
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0
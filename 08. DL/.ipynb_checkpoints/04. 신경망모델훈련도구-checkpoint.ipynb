# %% [markdown]
# - 머신러닝 알고리즘은 모델의 구조가 어느정도 고정되어 있음
#     - 좋은 성능을 내기 위해서는 매개변수를 조정하고 훈련하는 과정을 반복
# - 딥러닝은 구조를 직접 설계해야함
#     - 좋은 성능을 내기 위해 다룰 수 있는 다양한 개념과 도구들을 이해할 필요가 있음

# %% [markdown]
# # 손실 곡선
#
# - 케라스의 fit() 메서드는 History 클래스의 객체를 반환
#     - History 객체 : 훈련 과정에서 계산한 지표(손실과 정확도값)가 저장되어 있음
#     - 이 값을 사용하여 그래프를 그려서 훈련 성과를 확인

# %%
from tensorflow import keras
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# %%
scaled_train = x_train / 255
scaled_train, scaled_val, y_train, y_val = train_test_split(scaled_train, y_train, test_size = 0.2, random_state = 12)

# %%
# 모델 정의
def model_fn(a_layer = None):
    model = keras.Sequential()
    model.add(keras.layers.Flatten(input_shape = (28, 28)))
    model.add(keras.layers.Dense(100, activation = "relu"))
    
    if a_layer:
        model.add(a_layer)
    model.add(keras.layers.Dense(10, activation = "softmax"))
    
    return model

# %%
model = model_fn()
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 100)                 │          78,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,010 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 79,510 (310.59 KB)
#  Trainable params: 79,510 (310.59 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss = "sparse_categorical_crossentropy", metrics = ["accuracy"])

# %%
history = model.fit(scaled_train, y_train, epochs = 5, verbose = 1)
# Out:
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 975us/step - accuracy: 0.7644 - loss: 0.6837
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 974us/step - accuracy: 0.8544 - loss: 0.4085
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 961us/step - accuracy: 0.8707 - loss: 0.3585
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 990us/step - accuracy: 0.8781 - loss: 0.3356
# Epoch 5/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 1s 980us/step - accuracy: 0.8841 - loss: 0.3190

# %% [markdown]
# - verbose
#     - 훈련 과정 출력을 조정
#     - 0 : 훈련 과정 출력 안함
#     - 1 : 에포크마다 진행 막대와 함께 지표 출력
#     - 2 : 진행 막대를 빼고 출력

# %%
# history 객체 확인
print(history.history.keys())
# Out:
# dict_keys(['accuracy', 'loss'])

# %% [markdown]
# - 기본적으로 손실을 계산에서 compile 에서 accuracy를 추가하여서 loss와 accuracy가 포함됨

# %%
plt.figure()

plt.plot(history.history["loss"])

plt.xlabel("epoch")
plt.ylabel("loss")
plt.show()

# %%
plt.figure()

plt.plot(history.history["accuracy"])

plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.show()

# %%
# epoch를 20으로 늘려서 그래프 확인
model = model_fn()
model.compile(loss = "sparse_categorical_crossentropy", metrics = ["accuracy"])
history = model.fit(scaled_train, y_train, epochs = 20)
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7651 - loss: 0.6723
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8542 - loss: 0.4053
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8698 - loss: 0.3630
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8785 - loss: 0.3359
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8835 - loss: 0.3242
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8897 - loss: 0.3030
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8939 - loss: 0.2983
# Epoch 8/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8981 - loss: 0.2866
# Epoch 9/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8989 - loss: 0.2814
# Epoch 10/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9020 - loss: 0.2727
# Epoch 11/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9060 - loss: 0.2702
# Epoch 12/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9109 - loss: 0.2517
# Epoch 13/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9121 - loss: 0.2488
# Epoch 14/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9144 - loss: 0.2431
# Epoch 15/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9148 - loss: 0.2465
# Epoch 16/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9182 - loss: 0.2337
# Epoch 17/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9203 - loss: 0.2313
# Epoch 18/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9186 - loss: 0.2345
# Epoch 19/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9217 - loss: 0.2186
# Epoch 20/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9225 - loss: 0.2218

# %%
plt.figure()

plt.plot(history.history["loss"], label = "loss")
plt.plot(history.history["accuracy"], label = "acc")

plt.legend()
plt.xlabel("epoch")
plt.show()

# %% [markdown]
# # 검증 손실
#
# - 에포크에 따른 과대적합과 과소적합을 파악하려면 검증 세트에 대한 점수도 확인해야함
# - 케라스에서는 fit() 메서드에 검증 데이터를 전달할 수 있음

# %%
model = model_fn()
model.compile(loss = "sparse_categorical_crossentropy", metrics = ["accuracy"])
history = model.fit(scaled_train, y_train, epochs = 20, validation_data = (scaled_val, y_val))
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7629 - loss: 0.6846 - val_accuracy: 0.8518 - val_loss: 0.4062
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8539 - loss: 0.4072 - val_accuracy: 0.8725 - val_loss: 0.3769
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8701 - loss: 0.3592 - val_accuracy: 0.8717 - val_loss: 0.3659
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8792 - loss: 0.3391 - val_accuracy: 0.8752 - val_loss: 0.3690
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8833 - loss: 0.3229 - val_accuracy: 0.8725 - val_loss: 0.3808
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8882 - loss: 0.3116 - val_accuracy: 0.8860 - val_loss: 0.3481
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8932 - loss: 0.2967 - val_accuracy: 0.8846 - val_loss: 0.3488
# Epoch 8/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8931 - loss: 0.3014 - val_accuracy: 0.8889 - val_loss: 0.3450
# Epoch 9/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9010 - loss: 0.2784 - val_accuracy: 0.8818 - val_loss: 0.3654
# Epoch 10/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9032 - loss: 0.2732 - val_accuracy: 0.8767 - val_loss: 0.3972
# Epoch 11/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9025 - loss: 0.2708 - val_accuracy: 0.8912 - val_loss: 0.3596
# Epoch 12/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9088 - loss: 0.2625 - val_accuracy: 0.8883 - val_loss: 0.3707
# Epoch 13/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9107 - loss: 0.2526 - val_accuracy: 0.8892 - val_loss: 0.3688
# Epoch 14/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9128 - loss: 0.2523 - val_accuracy: 0.8856 - val_loss: 0.3967
# Epoch 15/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9139 - loss: 0.2450 - val_accuracy: 0.8816 - val_loss: 0.4084
# Epoch 16/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9171 - loss: 0.2352 - val_accuracy: 0.8843 - val_loss: 0.4106
# Epoch 17/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9169 - loss: 0.2362 - val_accuracy: 0.8897 - val_loss: 0.3734
# Epoch 18/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9211 - loss: 0.2309 - val_accuracy: 0.8890 - val_loss: 0.4058
# Epoch 19/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9206 - loss: 0.2246 - val_accuracy: 0.8910 - val_loss: 0.3795
# Epoch 20/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9234 - loss: 0.2226 - val_accuracy: 0.8896 - val_loss: 0.4267

# %%
plt.figure()

plt.plot(history.history["loss"], label = "loss")
plt.plot(history.history["accuracy"], label = "acc")
plt.plot(history.history["val_loss"], label = "val_loss")
plt.plot(history.history["val_accuracy"], label = "val_acc")

plt.legend()
plt.xlabel("epoch")
plt.show()

# %% [markdown]
# - 훈련 손실은 계속 감소하는데 검증 손실은 감소하다가 상승하여 과대적합 모델이 만들어짐
#     - 검증 손실이 상승하는 시점을 가능한한 뒤로 늦출 필요가 있음

# %%
# Adam 옵티마이저 선택
model = model_fn()
model.compile(optimizer = "adam", loss = "sparse_categorical_crossentropy", metrics = ["accuracy"])
history = model.fit(scaled_train, y_train, epochs = 20, validation_data = (scaled_val, y_val))
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7577 - loss: 0.6965 - val_accuracy: 0.8595 - val_loss: 0.4016
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8536 - loss: 0.4090 - val_accuracy: 0.8665 - val_loss: 0.3787
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8716 - loss: 0.3545 - val_accuracy: 0.8763 - val_loss: 0.3445
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8793 - loss: 0.3292 - val_accuracy: 0.8802 - val_loss: 0.3347
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8879 - loss: 0.3054 - val_accuracy: 0.8802 - val_loss: 0.3368
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8894 - loss: 0.2997 - val_accuracy: 0.8799 - val_loss: 0.3414
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8971 - loss: 0.2779 - val_accuracy: 0.8824 - val_loss: 0.3269
# Epoch 8/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8995 - loss: 0.2724 - val_accuracy: 0.8888 - val_loss: 0.3148
# Epoch 9/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9009 - loss: 0.2631 - val_accuracy: 0.8913 - val_loss: 0.3117
# Epoch 10/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9061 - loss: 0.2513 - val_accuracy: 0.8899 - val_loss: 0.3081
# Epoch 11/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9065 - loss: 0.2485 - val_accuracy: 0.8840 - val_loss: 0.3321
# Epoch 12/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9106 - loss: 0.2381 - val_accuracy: 0.8860 - val_loss: 0.3193
# Epoch 13/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9121 - loss: 0.2358 - val_accuracy: 0.8909 - val_loss: 0.3154
# Epoch 14/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9130 - loss: 0.2298 - val_accuracy: 0.8911 - val_loss: 0.3185
# Epoch 15/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9191 - loss: 0.2175 - val_accuracy: 0.8898 - val_loss: 0.3184
# Epoch 16/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9197 - loss: 0.2138 - val_accuracy: 0.8870 - val_loss: 0.3305
# Epoch 17/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9193 - loss: 0.2108 - val_accuracy: 0.8926 - val_loss: 0.3145
# Epoch 18/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9223 - loss: 0.2016 - val_accuracy: 0.8940 - val_loss: 0.3225
# Epoch 19/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9244 - loss: 0.1987 - val_accuracy: 0.8870 - val_loss: 0.3433
# Epoch 20/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9271 - loss: 0.1926 - val_accuracy: 0.8941 - val_loss: 0.3173

# %%
plt.figure()

plt.plot(history.history["loss"], label = "loss")
plt.plot(history.history["accuracy"], label = "acc")
plt.plot(history.history["val_loss"], label = "val_loss")
plt.plot(history.history["val_accuracy"], label = "val_acc")

plt.legend()
plt.xlabel("epoch")
plt.show()

# %% [markdown]
# - RMSprop 을 사용할 때보다 검증 손실 그래프의 감소 추세가 갈게 이어지고 있어 Adam 옵티마이저가 이 데이터셋에 잘 맞는 것으로 보임

# %% [markdown]
# # 드롭아웃(dropout)
#
# <img src = "./image/dropout.png">

# %% [markdown]
# - 훈련과정에서 층의 일부 유닛을 랜덤하게 끄는 것으로(출력을 0으로 만드는 것으로) 과대적합을 방지
#     - 특정 유닛에 과대하게 의존하는 것을 줄일 수 있음
#     - 일부 유닛의 출력이 없을 수 있다는 것을 감안하여 학습을 하게 됨
#         - 모든 입력값에 대해 충분한 주의를 기울이는 방향으로 학습
# - 드롭아웃은 케라스에서 Dropout 클래스로 제공
# - 특정 층 뒤에 드롭아웃을 두어 해당 층의 출력을 랜덤하게 0으로 만듦
# - Flatten과 마찬가지로 층처럼 사용되지만 훈련되는 모델 파라미터는 없음

# %%
model = model_fn(keras.layers.Dropout(0.3))
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten_5 (Flatten)                  │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 100)                 │          78,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 100)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 10)                  │           1,010 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 79,510 (310.59 KB)
#  Trainable params: 79,510 (310.59 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# - 드롭아웃층은 입력과 출력의 크기가 같음
#     - 일부 유닛의 출력을 0으로 만들지만 전체 출력 배열의 크기를 바꾸지 않음
# - 모델 훈련이 끝난 후에 평가나 예측을 수행할 때에는 드롭아웃을 적용하지 않아야 함
#     - 훈련된 모든 유닛을 사용해야 올바른 예측을 수행할 수 있기 때문에
#     - 케라스에서는 모델을 평가와 예측에 사용할 때에는 자동으로 드롭아웃을 적용하지 않음

# %%
model.compile(optimizer = "adam", loss = "sparse_categorical_crossentropy", metrics = ["accuracy"])

# %%
history = model.fit(scaled_train, y_train, epochs = 20, validation_data = (scaled_val, y_val))
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7252 - loss: 0.7772 - val_accuracy: 0.8568 - val_loss: 0.4031
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8390 - loss: 0.4464 - val_accuracy: 0.8653 - val_loss: 0.3746
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8473 - loss: 0.4129 - val_accuracy: 0.8631 - val_loss: 0.3674
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8603 - loss: 0.3879 - val_accuracy: 0.8788 - val_loss: 0.3420
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8646 - loss: 0.3705 - val_accuracy: 0.8773 - val_loss: 0.3400
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8721 - loss: 0.3556 - val_accuracy: 0.8812 - val_loss: 0.3303
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8702 - loss: 0.3494 - val_accuracy: 0.8724 - val_loss: 0.3536
# Epoch 8/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8723 - loss: 0.3426 - val_accuracy: 0.8816 - val_loss: 0.3306
# Epoch 9/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8793 - loss: 0.3301 - val_accuracy: 0.8844 - val_loss: 0.3223
# Epoch 10/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8788 - loss: 0.3213 - val_accuracy: 0.8857 - val_loss: 0.3193
# Epoch 11/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8830 - loss: 0.3173 - val_accuracy: 0.8899 - val_loss: 0.3156
# Epoch 12/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8827 - loss: 0.3102 - val_accuracy: 0.8919 - val_loss: 0.3045
# Epoch 13/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8820 - loss: 0.3062 - val_accuracy: 0.8893 - val_loss: 0.3098
# Epoch 14/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8862 - loss: 0.3035 - val_accuracy: 0.8859 - val_loss: 0.3303
# Epoch 15/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8868 - loss: 0.2966 - val_accuracy: 0.8902 - val_loss: 0.3144
# Epoch 16/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8886 - loss: 0.2926 - val_accuracy: 0.8917 - val_loss: 0.3094
# Epoch 17/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8932 - loss: 0.2854 - val_accuracy: 0.8907 - val_loss: 0.3170
# Epoch 18/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8937 - loss: 0.2823 - val_accuracy: 0.8840 - val_loss: 0.3370
# Epoch 19/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8931 - loss: 0.2813 - val_accuracy: 0.8892 - val_loss: 0.3162
# Epoch 20/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8969 - loss: 0.2727 - val_accuracy: 0.8937 - val_loss: 0.3070

# %%
plt.figure()

plt.plot(history.history["loss"], label = "loss")
plt.plot(history.history["accuracy"], label = "acc")
plt.plot(history.history["val_loss"], label = "val_loss")
plt.plot(history.history["val_accuracy"], label = "val_acc")

plt.legend()
plt.xlabel("epoch")
plt.show()

# %% [markdown]
# - 앞선 방법들에 비해 loss와 acc가 비교적 일정하게 유지됨

# %% [markdown]
# # 모델 저장과 복원

# %%
model = model_fn(keras.layers.Dropout(0.3))
model.compile(optimizer = "adam", loss = "sparse_categorical_crossentropy", metrics = ["accuracy"])
history = model.fit(scaled_train, y_train, epochs = 12, validation_data = (scaled_val, y_val))
# Out:
# Epoch 1/12
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7295 - loss: 0.7766 - val_accuracy: 0.8384 - val_loss: 0.4395
# Epoch 2/12
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8396 - loss: 0.4490 - val_accuracy: 0.8656 - val_loss: 0.3789
# Epoch 3/12
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8515 - loss: 0.4124 - val_accuracy: 0.8747 - val_loss: 0.3514
# Epoch 4/12
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8594 - loss: 0.3855 - val_accuracy: 0.8757 - val_loss: 0.3444
# Epoch 5/12
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8627 - loss: 0.3704 - val_accuracy: 0.8779 - val_loss: 0.3360
# Epoch 6/12
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8708 - loss: 0.3529 - val_accuracy: 0.8823 - val_loss: 0.3318
# Epoch 7/12
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8731 - loss: 0.3410 - val_accuracy: 0.8852 - val_loss: 0.3186
# Epoch 8/12
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8779 - loss: 0.3315 - val_accuracy: 0.8813 - val_loss: 0.3414
# Epoch 9/12
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8803 - loss: 0.3288 - val_accuracy: 0.8890 - val_loss: 0.3155
# Epoch 10/12
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8816 - loss: 0.3201 - val_accuracy: 0.8727 - val_loss: 0.3439
# Epoch 11/12
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8850 - loss: 0.3118 - val_accuracy: 0.8884 - val_loss: 0.3120
# Epoch 12/12
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8858 - loss: 0.3091 - val_accuracy: 0.8857 - val_loss: 0.3176

# %%
print(history.history["val_loss"].index(min(history.history["val_loss"])) , min(history.history["val_loss"]))
# Out:
# 10 0.31201931834220886

# %% [markdown]
# - 케라스 모델은 모델의 파라미터를 저장하는 save_weights() 메서드를 제공
# - 모델 구조와 모델 파라미터를 제공하는 save() 메서드도 제공

# %%
model.save_weights("./model/model_weights.weights.h5")

# %%
model.save("./model/model-whole.keras")

# %% [markdown]
# # 모델 파라미터만 읽어오기

# %%
model = model_fn(keras.layers.Dropout(0.3))
model.load_weights("./model/model_weights.weights.h5")

# %% [markdown]
# - load_weights() 메서드를 사용하면 save_weights()로 저장했던 모델과 정확히 같은 구조를 가져야 함

# %%
val_labels = np.argmax(model.predict(scaled_val), axis = 1)
# Out:
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step

# %%
val_labels
# Out:
# array([3, 0, 8, ..., 0, 7, 5], dtype=int64)

# %%
y_val
# Out:
# array([3, 0, 8, ..., 0, 7, 5], dtype=uint8)

# %%
np.mean(val_labels == y_val)
# Out:
# 0.8856666666666667

# %% [markdown]
# - 케라스의 predict() 메서드는 모델의 예측을 수행
#     - 종속변수가 10개의 클래스로 이루어져 있기 때문에 각 클래스에 대한 확률을 반환
# - predict() 결과에서 가장 큰 값을 고르기 위해 argmax() 함수를 사용
#     - 배열에서 가장 큰 값의 인덱스를 반환
#     - 몇 번째 클래스에 대한 확률값이 가장 큰 지 반환
#         - 몇 번째 클래스로 예측했는지 알 수 있음
# - argmax()로 고른 인덱스와 타깃 인덱스를 비교하면 같으면 True, 다르면 False
#     - 위 값의 평균을 구하면 정확도가 됨

# %% [markdown]
# ### 모델 전체 읽어오기

# %%
model = keras.models.load_model("./model/model-whole.keras")

# %%
model.evaluate(scaled_val, y_val)
# Out:
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - accuracy: 0.8864 - loss: 0.3029
# [0.3176010549068451, 0.8856666684150696]

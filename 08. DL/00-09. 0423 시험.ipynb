# %%
import pandas as pd
from tensorflow import keras
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import re
from konlpy.tag import Okt
from tensorflow.keras.preprocessing.text import Tokenizer

# %% [markdown]
# 제시된 다산콜센터 데이터에서 “문서” 컬럼을 독립변수로 하여 “분류” 컬럼 을 예측하는 딥러닝 모델을 개발하고
#
# 모델 개발 과정과 테스트 데이터셋에 대한 accuracy를 답안으로 작성하시오

# %% [markdown]
# ### 데이터 확인

# %%
df = pd.read_csv("./data/다산콜재단.csv")

# %%
df.head()
# Out:
#      번호  분류                           제목  \
# 0  2645  복지                  아빠 육아휴직 장려금
# 1  2644  경제            [서울산업진흥원] 서울메이드란?
# 2  2642  복지  광진맘택시 운영(임산부,영아 양육가정 전용 택시)
# 3  2641  복지               마포 뇌병변장애인 비전센터
# 4  2640  행정    2021년도 중1·고1 신입생 입학준비금 지원
#
#                                                   내용      내용번호  \
# 0  아빠 육아휴직 장려금   업무개요  남성근로자의 육아휴직을 장려하고 양육에 따른 경...  23522464
# 1  서울산업진흥원 서울메이드란 서울의 감성을 담은 다양하고 새로운 경험을 제공하기 위해...  23194045
# 2  광진맘택시 운영임산부영아 양육가정 전용 택시  업무개요 교통약자인 임산부와 영아가정...  22904492
# 3  마포 뇌병변장애인 비전센터 마포뇌병변장애인 비전센터 운영   구분 내용  목적  학...  22477798
# 4  년도 중고 신입생 입학준비금 지원  업무개요  서울시는 전국 최초로 년도부터 개 자...  22227896
#
#                                                   문서
# 0  아빠 육아휴직 장려금아빠 육아휴직 장려금   업무개요  남성근로자의 육아휴직을 장려...
# 1  [서울산업진흥원] 서울메이드란?서울산업진흥원 서울메이드란 서울의 감성을 담은 다양하...
# 2  광진맘택시 운영(임산부,영아 양육가정 전용 택시)광진맘택시 운영임산부영아 양육가정 ...
# 3  마포 뇌병변장애인 비전센터마포 뇌병변장애인 비전센터 마포뇌병변장애인 비전센터 운영 ...
# 4  2021년도 중1·고1 신입생 입학준비금 지원년도 중고 신입생 입학준비금 지원  업...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2138 entries, 0 to 2137
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   번호      2138 non-null   int64
#  1   분류      2138 non-null   object
#  2   제목      2138 non-null   object
#  3   내용      2138 non-null   object
#  4   내용번호    2138 non-null   int64
#  5   문서      2138 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 100.3+ KB

# %%
df["분류"].value_counts()
# Out:
# 분류
# 행정    1098
# 경제     823
# 복지     217
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                 번호          내용번호
# count  2138.000000  2.138000e+03
# mean   1414.881197  3.224558e+06
# std     688.608670  2.154023e+06
# min       3.000000  2.894089e+06
# 25%     863.250000  2.895404e+06
# 50%    1424.500000  2.896546e+06
# 75%    1989.750000  2.897575e+06
# max    2645.000000  2.352246e+07

# %%
df.shape
# Out:
# (2138, 6)

# %% [markdown]
# ### 간단한 전처리

# %%
# 한글 외의 다른 문자 제거
df["문서"] = df["문서"].map(lambda x: re.sub("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]", "", x))

# %%
df.head()
# Out:
#      번호  분류                           제목  \
# 0  2645  복지                  아빠 육아휴직 장려금
# 1  2644  경제            [서울산업진흥원] 서울메이드란?
# 2  2642  복지  광진맘택시 운영(임산부,영아 양육가정 전용 택시)
# 3  2641  복지               마포 뇌병변장애인 비전센터
# 4  2640  행정    2021년도 중1·고1 신입생 입학준비금 지원
#
#                                                   내용      내용번호  \
# 0  아빠 육아휴직 장려금   업무개요  남성근로자의 육아휴직을 장려하고 양육에 따른 경...  23522464
# 1  서울산업진흥원 서울메이드란 서울의 감성을 담은 다양하고 새로운 경험을 제공하기 위해...  23194045
# 2  광진맘택시 운영임산부영아 양육가정 전용 택시  업무개요 교통약자인 임산부와 영아가정...  22904492
# 3  마포 뇌병변장애인 비전센터 마포뇌병변장애인 비전센터 운영   구분 내용  목적  학...  22477798
# 4  년도 중고 신입생 입학준비금 지원  업무개요  서울시는 전국 최초로 년도부터 개 자...  22227896
#
#                                                   문서
# 0  아빠 육아휴직 장려금아빠 육아휴직 장려금   업무개요  남성근로자의 육아휴직을 장려...
# 1  서울산업진흥원 서울메이드란서울산업진흥원 서울메이드란 서울의 감성을 담은 다양하고 새...
# 2  광진맘택시 운영임산부영아 양육가정 전용 택시광진맘택시 운영임산부영아 양육가정 전용 ...
# 3  마포 뇌병변장애인 비전센터마포 뇌병변장애인 비전센터 마포뇌병변장애인 비전센터 운영 ...
# 4  년도 중고 신입생 입학준비금 지원년도 중고 신입생 입학준비금 지원  업무개요  서울...

# %%
# 10글자 미만의 문서가 없는 것을 확인
len(df[df["문서"].map(lambda x: len(x.strip()) < 10)])
# Out:
# 0

# %%
df[df["문서"].map(lambda x: len(x.strip()) < 10)].head()
# Out:
# Empty DataFrame
# Columns: [번호, 분류, 제목, 내용, 내용번호, 문서]
# Index: []

# %%
# 중복 데이터 확인
df[df["문서"].duplicated(keep = False)].sort_values("문서")
# Out:
#        번호  분류                    제목  \
# 649  1874  행정  불문경고도 소청심사의 대상이 되나요?
# 650  1873  행정  불문경고도 소청심사의 대상이 되나요?
#
#                                                     내용     내용번호  \
# 649  불문경고도 소청심사의 대상이 되나요불문경고는 신분상의 불이익을 초래하는 법률상의 효...  2895139
# 650  불문경고도 소청심사의 대상이 되나요불문경고는 신분상의 불이익을 초래하는 법률상의 효...  2895150
#
#                                                     문서
# 649  불문경고도 소청심사의 대상이 되나요불문경고도 소청심사의 대상이 되나요불문경고는 신분...
# 650  불문경고도 소청심사의 대상이 되나요불문경고도 소청심사의 대상이 되나요불문경고는 신분...

# %%
# 중복 제거
df = df.drop_duplicates(subset = ["문서"])

# %%
df.shape
# Out:
# (2137, 6)

# %% [markdown]
# ### 불필요한 피처 제거
#
# - 독립변수 '문서'와 종속변수 '분류' 를 제외한 모든 피처 제거

# %%
df = df.drop(["번호", "제목", "내용", "내용번호"], axis = 1)

# %%
df.head()
# Out:
#    분류                                                 문서
# 0  복지  아빠 육아휴직 장려금아빠 육아휴직 장려금   업무개요  남성근로자의 육아휴직을 장려...
# 1  경제  서울산업진흥원 서울메이드란서울산업진흥원 서울메이드란 서울의 감성을 담은 다양하고 새...
# 2  복지  광진맘택시 운영임산부영아 양육가정 전용 택시광진맘택시 운영임산부영아 양육가정 전용 ...
# 3  복지  마포 뇌병변장애인 비전센터마포 뇌병변장애인 비전센터 마포뇌병변장애인 비전센터 운영 ...
# 4  행정  년도 중고 신입생 입학준비금 지원년도 중고 신입생 입학준비금 지원  업무개요  서울...

# %% [markdown]
# ### 토큰화

# %%
okt = Okt()

# %%
df["token"] = df["문서"].map(lambda x: okt.morphs(x, stem = True))

# %%
df.head()
# Out:
#    분류                                                 문서  \
# 0  복지  아빠 육아휴직 장려금아빠 육아휴직 장려금   업무개요  남성근로자의 육아휴직을 장려...
# 1  경제  서울산업진흥원 서울메이드란서울산업진흥원 서울메이드란 서울의 감성을 담은 다양하고 새...
# 2  복지  광진맘택시 운영임산부영아 양육가정 전용 택시광진맘택시 운영임산부영아 양육가정 전용 ...
# 3  복지  마포 뇌병변장애인 비전센터마포 뇌병변장애인 비전센터 마포뇌병변장애인 비전센터 운영 ...
# 4  행정  년도 중고 신입생 입학준비금 지원년도 중고 신입생 입학준비금 지원  업무개요  서울...
#
#                                                token
# 0  [아빠, 육아휴직, 장려, 금, 아빠, 육아휴직, 장려, 금, 업무, 개요, 남성,...
# 1  [서, 울, 산업, 진흥, 원, 서, 울, 메이드, 란, 서울, 산업, 진흥, 원,...
# 2  [광진, 맘, 택시, 운영, 임산부, 영아, 양육, 가정, 전용, 택시, 광진, 맘...
# 3  [마포, 뇌, 병변, 장애인, 비다, 센터, 마포, 뇌, 병변, 장애인, 비다, 센...
# 4  [년도, 중고, 신입생, 입학, 준비, 금, 지원, 년도, 중고, 신입생, 입학, ...

# %%
df.to_csv("./다산콜재단_token.csv")

# %% [markdown]
# ### 정수 인코딩

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts(df["token"])

# %%
tokenizer.word_index
# Out:
# {'하다': 1,
#  '의': 2,
#  '에': 3,
#  '을': 4,
#  '를': 5,
#  '이': 6,
#  '있다': 7,
#  '은': 8,
#  '되다': 9,
#  '및': 10,
#  '는': 11,
#  '으로': 12,
#  '등': 13,
#  '한': 14,
#  '움': 15,
#  '돋다': 16,
#  '가': 17,
#  '경우': 18,
#  '수': 19,
#  '사업': 20,
#  '과': 21,
#  '에서': 22,
#  '로': 23,
#  '시설': 24,
#  '시': 25,
#  '자': 26,
#  '인': 27,
#  '신청': 28,
#  '제': 29,
#  '관리': 30,
#  '지원': 31,
#  '주택': 32,
#  '일': 33,
#  '이다': 34,
#  '년': 35,
#  '적': 36,
#  '센터': 37,
#  '또는': 38,
#  '하고': 39,
#  '서울시': 40,
#  '받다': 41,
#  '계획': 42,
#  '원': 43,
#  '운영': 44,
#  '이상': 45,
#  '월': 46,
#  '와': 47,
#  '교육': 48,
#  '사항': 49,
#  '어떻다': 50,
#  '업무': 51,
#  '내용': 52,
#  '서': 53,
#  '서울': 54,
#  '지': 55,
#  '공': 56,
#  '중': 57,
#  '것': 58,
#  '관련': 59,
#  '대상': 60,
#  '이용': 61,
#  '동': 62,
#  '지역': 63,
#  '위': 64,
#  '무엇': 65,
#  '관': 66,
#  '따르다': 67,
#  '후': 68,
#  '기준': 69,
#  '도시': 70,
#  '에는': 71,
#  '건축물': 72,
#  '설치': 73,
#  '확인': 74,
#  '신고': 75,
#  '가능하다': 76,
#  '해당': 77,
#  '방법': 78,
#  '내': 79,
#  '되어다': 80,
#  '공무원': 81,
#  '없다': 82,
#  '제조': 83,
#  '규정': 84,
#  '변경': 85,
#  '홈페이지': 86,
#  '의하다': 87,
#  '건축': 88,
#  '주민': 89,
#  '법': 90,
#  '정보': 91,
#  '구': 92,
#  '기관': 93,
#  '도로': 94,
#  '위원회': 95,
#  '민원': 96,
#  '시행': 97,
#  '사용': 98,
#  '시간': 99,
#  '여': 100,
#  '등록': 101,
#  '비': 102,
#  '함': 103,
#  '상': 104,
#  '인가요': 105,
#  '기간': 106,
#  '상담': 107,
#  '그': 108,
#  '도': 109,
#  '조': 110,
#  '아니다': 111,
#  '개': 112,
#  '명': 113,
#  '않다': 114,
#  '문의': 115,
#  '건설': 116,
#  '입': 117,
#  '니까': 118,
#  '서비스': 119,
#  '이란': 120,
#  '접수': 121,
#  '장': 122,
#  '하': 123,
#  '가능': 124,
#  '에게': 125,
#  '회': 126,
#  '사': 127,
#  '대한': 128,
#  '서류': 129,
#  '들': 130,
#  '토지': 131,
#  '제출': 132,
#  '말': 133,
#  '기술': 134,
#  '층': 135,
#  '공사': 136,
#  '환경': 137,
#  '기': 138,
#  '성': 139,
#  '대': 140,
#  '처리': 141,
#  '구역': 142,
#  '별': 143,
#  '소': 144,
#  '하나요': 145,
#  '청소년': 146,
#  '사회': 147,
#  '기타': 148,
#  '복지': 149,
#  '전': 150,
#  '고': 151,
#  '포함': 152,
#  '단체': 153,
#  '분': 154,
#  '연': 155,
#  '개발': 156,
#  '구청': 157,
#  '필요하다': 158,
#  '각': 159,
#  '이하': 160,
#  '발급': 161,
#  '나': 162,
#  '허가': 163,
#  '부터': 164,
#  '주': 165,
#  '행정': 166,
#  '면적': 167,
#  '어린이집': 168,
#  '만': 169,
#  '구분': 170,
#  '세': 171,
#  '보육': 172,
#  '안내': 173,
#  '까지': 174,
#  '란': 175,
#  '시민': 176,
#  '지급': 177,
#  '생활': 178,
#  '추진': 179,
#  '정': 180,
#  '행위': 181,
#  '주거': 182,
#  '문화': 183,
#  '서울특별시': 184,
#  '안전': 185,
#  '지정': 186,
#  '참여': 187,
#  '디자인': 188,
#  '담당': 189,
#  '카드': 190,
#  '농업': 191,
#  '만원': 192,
#  '의료': 193,
#  '분양': 194,
#  '팀': 195,
#  '장애인': 196,
#  '정비': 197,
#  '실': 198,
#  '전화': 199,
#  '검사': 200,
#  '자격': 201,
#  '절차': 202,
#  '물': 203,
#  '신청서': 204,
#  '프로그램': 205,
#  '아파트': 206,
#  '주소': 207,
#  '부서': 208,
#  '이나': 209,
#  '자료': 210,
#  '여부': 211,
#  '실시': 212,
#  '시스템': 213,
#  '제공': 214,
#  '급': 215,
#  '적용': 216,
#  '방문': 217,
#  '개요': 218,
#  '학교': 219,
#  '단': 220,
#  '심의': 221,
#  '차': 222,
#  '분야': 223,
#  '종합': 224,
#  '제외': 225,
#  '현황': 226,
#  '활동': 227,
#  '대상자': 228,
#  '선정': 229,
#  '다': 230,
#  '조합': 231,
#  '반': 232,
#  '보호': 233,
#  '제한': 234,
#  '가족': 235,
#  '교통': 236,
#  '모집': 237,
#  '인터넷': 238,
#  '대하': 239,
#  '지구': 240,
#  '미만': 241,
#  '개인': 242,
#  '회의': 243,
#  '심사': 244,
#  '행사': 245,
#  '금액': 246,
#  '위해': 247,
#  '문': 248,
#  '이내': 249,
#  '목적': 250,
#  '통해': 251,
#  '법률': 252,
#  '번': 253,
#  '간': 254,
#  '범위': 255,
#  '에서는': 256,
#  '계약': 257,
#  '이며': 258,
#  '항': 259,
#  '가입': 260,
#  '소득': 261,
#  '같다': 262,
#  '때': 263,
#  '요': 264,
#  '재산': 265,
#  '형': 266,
#  '위치': 267,
#  '제도': 268,
#  '다음': 269,
#  '인정': 270,
#  '의무': 271,
#  '장소': 272,
#  '신': 273,
#  '싶다': 274,
#  '용도': 275,
#  '발생': 276,
#  '본인': 277,
#  '무료': 278,
#  '작성': 279,
#  '결정': 280,
#  '권': 281,
#  '한국': 282,
#  '울': 283,
#  '건강': 284,
#  '길': 285,
#  '규모': 286,
#  '로서': 287,
#  '보상': 288,
#  '외': 289,
#  '정책': 290,
#  '소유자': 291,
#  '기업': 292,
#  '일반': 293,
#  '법인': 294,
#  '거나': 295,
#  '직무': 296,
#  '계': 297,
#  '구성': 298,
#  '보험': 299,
#  '증명서': 300,
#  '현재': 301,
#  '주요': 302,
#  '면': 303,
#  '창업': 304,
#  '시장': 305,
#  '개선': 306,
#  '공동': 307,
#  '공간': 308,
#  '보증': 309,
#  '비용': 310,
#  '총': 311,
#  '다른': 312,
#  '용': 313,
#  '거리': 314,
#  '공공': 315,
#  '직접': 316,
#  '국민': 317,
#  '담당자': 318,
#  '공급': 319,
#  '부담': 320,
#  '이전': 321,
#  '종': 322,
#  '경': 323,
#  '안': 324,
#  '임대': 325,
#  '감사': 326,
#  '우리': 327,
#  '대표': 328,
#  '당': 329,
#  '서대문구': 330,
#  '설립': 331,
#  '세대': 332,
#  '어디': 333,
#  '기본': 334,
#  '보다': 335,
#  '건물': 336,
#  '산업': 337,
#  '예산': 338,
#  '영업': 339,
#  '현장': 340,
#  '재정': 341,
#  '전화번호': 342,
#  '평일': 343,
#  '번지': 344,
#  '양': 345,
#  '결과': 346,
#  '대해': 347,
#  '이후': 348,
#  '아동': 349,
#  '일정': 350,
#  '관계': 351,
#  '드리다': 352,
#  '령': 353,
#  '경관': 354,
#  '화': 355,
#  '진행': 356,
#  '동의': 357,
#  '가정': 358,
#  '가스': 359,
#  '여성': 360,
#  '표시': 361,
#  '제호': 362,
#  '예정': 363,
#  '부분': 364,
#  '체험': 365,
#  '업체': 366,
#  '자치': 367,
#  '조례': 368,
#  '공원': 369,
#  '위반': 370,
#  '통': 371,
#  '수급': 372,
#  '법령': 373,
#  '임': 374,
#  '보조금': 375,
#  '직원': 376,
#  '수립': 377,
#  '당하다': 378,
#  '급여': 379,
#  '진료': 380,
#  '납부': 381,
#  '시청': 382,
#  '사업자': 383,
#  '부': 384,
#  '번호': 385,
#  '인가': 386,
#  '거주': 387,
#  '개월': 388,
#  '예': 389,
#  '회원': 390,
#  '약': 391,
#  '능력': 392,
#  '으로서': 393,
#  '대장': 394,
#  '모든': 395,
#  '활용': 396,
#  '없이': 397,
#  '과정': 398,
#  '다만': 399,
#  '영': 400,
#  '함께': 401,
#  '자치구': 402,
#  '출구': 403,
#  '판매': 404,
#  '열람': 405,
#  '공단': 406,
#  '자동차': 407,
#  '국가': 408,
#  '수행': 409,
#  '은평구': 410,
#  '공개': 411,
#  '온라인': 412,
#  '알': 413,
#  '재': 414,
#  '평가': 415,
#  '예약': 416,
#  '가다': 417,
#  '승인': 418,
#  '운동': 419,
#  '종류': 420,
#  '단지': 421,
#  '금': 422,
#  '구정': 423,
#  '조성': 424,
#  '검색': 425,
#  '별도': 426,
#  '호선': 427,
#  '공고': 428,
#  '유지': 429,
#  '송파구': 430,
#  '지방': 431,
#  '아': 432,
#  '근무': 433,
#  '곳': 434,
#  '타': 435,
#  '본': 436,
#  '바라다': 437,
#  '이상인': 438,
#  '에도': 439,
#  '점검': 440,
#  '에너지': 441,
#  '저': 442,
#  '협회': 443,
#  '근': 444,
#  '차량': 445,
#  '감리': 446,
#  '구비': 447,
#  '예방': 448,
#  '필요': 449,
#  '기획': 450,
#  '인하다': 451,
#  '알다': 452,
#  '요청': 453,
#  '훈련': 454,
#  '의원': 455,
#  '촉진': 456,
#  '가구': 457,
#  '식': 458,
#  '몇': 459,
#  '취업': 460,
#  '선': 461,
#  '관할': 462,
#  '희망': 463,
#  '노인': 464,
#  '협의': 465,
#  '방지': 466,
#  '취소': 467,
#  '업': 468,
#  '어린이': 469,
#  '등기': 470,
#  '물품': 471,
#  '통합': 472,
#  '기능': 473,
#  '산정': 474,
#  '규칙': 475,
#  '피해': 476,
#  '요금': 477,
#  '자본금': 478,
#  '기금': 479,
#  '이르다': 480,
#  '기계': 481,
#  '경제': 482,
#  '시기': 483,
#  '사유': 484,
#  '서다': 485,
#  '단위': 486,
#  '보건': 487,
#  '조사': 488,
#  '역': 489,
#  '반드시': 490,
#  '처분': 491,
#  '청장': 492,
#  '전용': 493,
#  '홍보': 494,
#  '기재': 495,
#  '통보': 496,
#  '대표자': 497,
#  '주민등록': 498,
#  '의거': 499,
#  '책임': 500,
#  '조치': 501,
#  '개정': 502,
#  '점': 503,
#  '액': 504,
#  '고시': 505,
#  '효율': 506,
#  '급식': 507,
#  '장애': 508,
#  '이행': 509,
#  '속': 510,
#  '미터': 511,
#  '청구': 512,
#  '부동산': 513,
#  '원칙': 514,
#  '초과': 515,
#  '일시': 516,
#  '식품': 517,
#  '확보': 518,
#  '청약': 519,
#  '이고': 520,
#  '거치다': 521,
#  '외부': 522,
#  '자녀': 523,
#  '각종': 524,
#  '중구': 525,
#  '사전': 526,
#  '콜센터': 527,
#  '설계': 528,
#  '위원': 529,
#  '주거지역': 530,
#  '이메일': 531,
#  '명의': 532,
#  '금융': 533,
#  '조회': 534,
#  '결제': 535,
#  '료': 536,
#  '기존': 537,
#  '시시': 538,
#  '자금': 539,
#  '인증': 540,
#  '소유': 541,
#  '높이': 542,
#  '제곱미터': 543,
#  '요건': 544,
#  '신용': 545,
#  '검토': 546,
#  '임대주택': 547,
#  '언제': 548,
#  '다양하다': 549,
#  '개별': 550,
#  '지다': 551,
#  '친환경': 552,
#  '재료': 553,
#  '작품': 554,
#  '설비': 555,
#  '대지': 556,
#  '설명': 557,
#  '사례': 558,
#  '민간': 559,
#  '증명': 560,
#  '자연': 561,
#  '교사': 562,
#  '류': 563,
#  '린': 564,
#  '행동강령': 565,
#  '불가': 566,
#  '인지': 567,
#  '앞': 568,
#  '청': 569,
#  '아래': 570,
#  '하나': 571,
#  '문자': 572,
#  '기초': 573,
#  '매': 574,
#  '추다': 575,
#  '경력': 576,
#  '연결': 577,
#  '편의': 578,
#  '수수료': 579,
#  '가격': 580,
#  '공직자': 581,
#  '못': 582,
#  '주자': 583,
#  '특별': 584,
#  '호': 585,
#  '날': 586,
#  '관심': 587,
#  '학습': 588,
#  '목': 589,
#  '비다': 590,
#  '소재': 591,
#  '완료': 592,
#  '개최': 593,
#  '사람': 594,
#  '무': 595,
#  '첨부': 596,
#  '향상': 597,
#  '대출': 598,
#  '특정': 599,
#  '권리': 600,
#  '다운로드': 601,
#  '년도': 602,
#  '유형': 603,
#  '보수': 604,
#  '연락처': 605,
#  '당직': 606,
#  '부패': 607,
#  '상위': 608,
#  '회복': 609,
#  '집': 610,
#  '광장': 611,
#  '교실': 612,
#  '용산구': 613,
#  '연장': 614,
#  '장이': 615,
#  '청사': 616,
#  '수련': 617,
#  '기술자': 618,
#  'ㅇ': 619,
#  '빌딩': 620,
#  '참가': 621,
#  '근로': 622,
#  '토': 623,
#  '양식': 624,
#  '등록증': 625,
#  '근거': 626,
#  '송파': 627,
#  '억원': 628,
#  '합': 629,
#  '임신': 630,
#  '임원': 631,
#  '폭': 632,
#  '종료': 633,
#  '병원': 634,
#  '아이': 635,
#  '일부': 636,
#  '선택': 637,
#  '주차장': 638,
#  '또한': 639,
#  '등본': 640,
#  '소개': 641,
#  '지방자치단체': 642,
#  '녹지': 643,
#  '은행': 644,
#  '접': 645,
#  '부과': 646,
#  '용적률': 647,
#  '우편': 648,
#  '대다': 649,
#  '시키다': 650,
#  '초등학교': 651,
#  '고객': 652,
#  '군': 653,
#  '집행': 654,
#  '호의': 655,
#  '조합원': 656,
#  '어느': 657,
#  '진흥': 658,
#  '전문가': 659,
#  '조정': 660,
#  '육아': 661,
#  '자세하다': 662,
#  '추가': 663,
#  '처': 664,
#  '발전': 665,
#  '투자': 666,
#  '사본': 667,
#  '가지': 668,
#  '별로': 669,
#  '제품': 670,
#  '품질': 671,
#  '광고': 672,
#  '의결': 673,
#  '입자': 674,
#  '준비': 675,
#  '학부모': 676,
#  '누구': 677,
#  '동물': 678,
#  '많다': 679,
#  '금지': 680,
#  '율': 681,
#  '사고': 682,
#  '발송': 683,
#  '취득': 684,
#  '의견': 685,
#  '자가': 686,
#  '우선': 687,
#  '전문': 688,
#  '참고': 689,
#  '사실': 690,
#  '강의': 691,
#  '전산': 692,
#  '방송': 693,
#  '철거': 694,
#  '차다': 695,
#  '인원': 696,
#  '공모': 697,
#  '구조': 698,
#  '안심': 699,
#  '형태': 700,
#  '공휴일': 701,
#  '선발': 702,
#  '라': 703,
#  '사진': 704,
#  '시험': 705,
#  '주체': 706,
#  '요구': 707,
#  '의미': 708,
#  '방식': 709,
#  '배정': 710,
#  '위험': 711,
#  '으로부터': 712,
#  '은평': 713,
#  '천': 714,
#  '대책': 715,
#  '증': 716,
#  '로부터': 717,
#  '매년': 718,
#  '주다': 719,
#  '뉴타운': 720,
#  '마포구': 721,
#  '국': 722,
#  '조직': 723,
#  '모두': 724,
#  '어르신': 725,
#  '거부': 726,
#  '상의': 727,
#  '소통': 728,
#  '사랑': 729,
#  '문서': 730,
#  '미술': 731,
#  '폐지': 732,
#  '계속': 733,
#  '맘': 734,
#  '계층': 735,
#  '신분증': 736,
#  '본부': 737,
#  '공지': 738,
#  '고지': 739,
#  '상금': 740,
#  '회계': 741,
#  '소속': 742,
#  '중계': 743,
#  '복지관': 744,
#  '상태': 745,
#  '마다': 746,
#  '열리다': 747,
#  '매주': 748,
#  '정도': 749,
#  '보고': 750,
#  '사무소': 751,
#  '지하철': 752,
#  '초': 753,
#  '장관': 754,
#  '게시': 755,
#  '택법': 756,
#  '별표': 757,
#  '입소': 758,
#  '보건소': 759,
#  '컨설팅': 760,
#  '구민': 761,
#  '방향': 762,
#  '통한': 763,
#  '불편': 764,
#  '운전': 765,
#  '토요일': 766,
#  '마을': 767,
#  '정부': 768,
#  '주제': 769,
#  '강연': 770,
#  '추천': 771,
#  '세부': 772,
#  '응모': 773,
#  '강': 774,
#  '어디서': 775,
#  '공용': 776,
#  '가로': 777,
#  '도서관': 778,
#  '건축법': 779,
#  '합계': 780,
#  '말다': 781,
#  '매월': 782,
#  '원하다': 783,
#  '구입': 784,
#  '주의': 785,
#  '도시농업': 786,
#  '시정': 787,
#  '조건': 788,
#  '최고': 789,
#  '수용': 790,
#  '관내': 791,
#  '학생': 792,
#  '부모': 793,
#  '체계': 794,
#  '일수': 795,
#  '지점': 796,
#  '확정': 797,
#  '활성화': 798,
#  '준': 799,
#  '팩스': 800,
#  '위생': 801,
#  '서식': 802,
#  '접속': 803,
#  '영상': 804,
#  '구축': 805,
#  '재개발': 806,
#  '바': 807,
#  '직': 808,
#  '토목': 809,
#  '으로써': 810,
#  '협력': 811,
#  '사무': 812,
#  '허용': 813,
#  '좋다': 814,
#  '발표': 815,
#  '행정처분': 816,
#  '명령': 817,
#  '창의': 818,
#  '안되다': 819,
#  '국제': 820,
#  '면허': 821,
#  '통신': 822,
#  '바로가기': 823,
#  '종로구': 824,
#  '시공': 825,
#  '확대': 826,
#  '강사': 827,
#  '주차': 828,
#  '치매': 829,
#  '판단': 830,
#  '쉬다': 831,
#  '위원장': 832,
#  '시도': 833,
#  '얼마': 834,
#  '건립': 835,
#  '신용카드': 836,
#  '상봉': 837,
#  '근로자': 838,
#  '서초구': 839,
#  '밉다': 840,
#  '최대': 841,
#  '맞춤': 842,
#  '출산': 843,
#  '한도': 844,
#  '항의': 845,
#  '총회': 846,
#  '제작': 847,
#  '기록': 848,
#  '보조': 849,
#  '적합하다': 850,
#  '놀이': 851,
#  '작': 852,
#  '통화': 853,
#  '역사': 854,
#  '직업': 855,
#  '관광': 856,
#  '정원': 857,
#  '수입': 858,
#  '사이트': 859,
#  '체육': 860,
#  '해외': 861,
#  '경계': 862,
#  '수화': 863,
#  '얻다': 864,
#  '부지': 865,
#  '경로': 866,
#  '이름': 867,
#  '상세': 868,
#  '증빙': 869,
#  '진단': 870,
#  '운행': 871,
#  '휴': 872,
#  '따라서': 873,
#  '가요': 874,
#  '경비': 875,
#  '제안': 876,
#  '자다': 877,
#  '과의': 878,
#  '입력': 879,
#  '자활': 880,
#  '설정': 881,
#  '정관': 882,
#  '임기': 883,
#  '강화': 884,
#  '직장': 885,
#  '개다': 886,
#  '전달': 887,
#  '보장': 888,
#  '전체': 889,
#  '상황': 890,
#  '수준': 891,
#  '노력': 892,
#  '마련': 893,
#  '지도': 894,
#  '표준': 895,
#  '도서': 896,
#  '시립': 897,
#  '천만원': 898,
#  '보내다': 899,
#  '미디어': 900,
#  '상징': 901,
#  '국토': 902,
#  '재건축': 903,
#  '기반시설': 904,
#  '공장': 905,
#  '고용': 906,
#  '돌보다': 907,
#  '구매': 908,
#  '성동구': 909,
#  '재단': 910,
#  '늘다': 911,
#  '자동': 912,
#  '우수': 913,
#  '여행': 914,
#  '일요일': 915,
#  '보전': 916,
#  '수강': 917,
#  '수당': 918,
#  '중앙': 919,
#  '성북구': 920,
#  '갖추다': 921,
#  '농': 922,
#  '감독': 923,
#  '관리자': 924,
#  '광진구': 925,
#  '동일하다': 926,
#  '영리': 927,
#  '사용자': 928,
#  '현': 929,
#  '안정': 930,
#  '모니터링': 931,
#  '인력': 932,
#  '버스': 933,
#  '업다': 934,
#  '주변': 935,
#  '수령': 936,
#  '포장': 937,
#  '전환': 938,
#  '전자': 939,
#  '컴퓨터': 940,
#  '계산': 941,
#  '해주다': 942,
#  '이라': 943,
#  '구간': 944,
#  '중소기업': 945,
#  '전국': 946,
#  '최초': 947,
#  '교육청': 948,
#  '특수': 949,
#  '종사': 950,
#  '연구': 951,
#  '더': 952,
#  '등급': 953,
#  '산': 954,
#  '체결': 955,
#  '자격증': 956,
#  '순위': 957,
#  '오다': 958,
#  '도입': 959,
#  '인사': 960,
#  '볼': 961,
#  '교류': 962,
#  '명칭': 963,
#  '불법': 964,
#  '장비': 965,
#  '인재': 966,
#  '진입': 967,
#  '궁금하다': 968,
#  '규약': 969,
#  '노원구': 970,
#  '공자': 971,
#  '유아': 972,
#  '택시': 973,
#  '두다': 974,
#  '마포': 975,
#  '방': 976,
#  '의처': 977,
#  '발간': 978,
#  '고려': 979,
#  '여건': 980,
#  '일월': 981,
#  '권한': 982,
#  '자재': 983,
#  '세대주': 984,
#  '마당': 985,
#  '모': 986,
#  '통지': 987,
#  '찾아가다': 988,
#  '야': 989,
#  '터미널': 990,
#  '편': 991,
#  '변화': 992,
#  '공유': 993,
#  '아동복': 994,
#  '창구': 995,
#  '지하': 996,
#  '도봉구': 997,
#  '증진': 998,
#  '거래': 999,
#  '길음': 1000,
#  ...}

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('아빠', 16),
#              ('육아휴직', 10),
#              ('장려', 6),
#              ('금', 89),
#              ('업무', 588),
#              ('개요', 171),
#              ('남성', 3),
#              ('근로자', 41),
#              ('의', 5030),
#              ('을', 4237),
#              ('하고', 693),
#              ('양육', 15),
#              ('에', 4578),
#              ('따르다', 484),
#              ('경제', 78),
#              ('적', 729),
#              ('부담', 117),
#              ('완화', 17),
#              ('함', 353),
#              ('으로써', 43),
#              ('일과', 7),
#              ('가정', 104),
#              ('생활', 208),
#              ('양립', 2),
#              ('및', 1880),
#              ('가족', 151),
#              ('친', 10),
#              ('화', 105),
#              ('인', 863),
#              ('사회', 253),
#              ('환경', 276),
#              ('조성', 88),
#              ('지원', 772),
#              ('대상', 531),
#              ('신청', 839),
#              ('일', 750),
#              ('기준', 479),
#              ('년', 732),
#              ('이상', 618),
#              ('계속', 48),
#              ('하다', 7233),
#              ('서초구', 41),
#              ('주민등록', 76),
#              ('되어다', 422),
#              ('있다', 2548),
#              ('자', 891),
#              ('자녀', 71),
#              ('되다', 2261),
#              ('경우', 1293),
#              ('기간', 343),
#              ('시', 900),
#              ('작일', 2),
#              ('이후', 107),
#              ('개월', 95),
#              ('부터', 230),
#              ('종료', 58),
#              ('이내', 143),
#              ('방법', 427),
#              ('온라인', 91),
#              ('서초', 11),
#              ('구청', 238),
#              ('홈페이지', 400),
#              ('경로', 40),
#              ('분야', 165),
#              ('별', 264),
#              ('정보', 382),
#              ('복지', 251),
#              ('영', 93),
#              ('유아', 35),
#              ('바로가기', 42),
#              ('방문', 172),
#              ('동', 527),
#              ('주민', 393),
#              ('센터', 711),
#              ('구', 382),
#              ('여', 358),
#              ('성', 274),
#              ('보육', 218),
#              ('과', 1234),
#              ('구비', 83),
#              ('서류', 290),
#              ('고용', 38),
#              ('발행', 31),
#              ('급여', 98),
#              ('지급', 209),
#              ('결정', 132),
#              ('통지서', 10),
#              ('부', 96),
#              ('등본', 57),
#              ('부세', 1),
#              ('대원', 3),
#              ('이름', 40),
#              ('전입', 23),
#              ('일자', 34),
#              ('포함', 243),
#              ('모든', 94),
#              ('구성원', 12),
#              ('번호', 96),
#              ('뒷', 6),
#              ('자리', 18),
#              ('밉다', 41),
#              ('내용', 554),
#              ('매월', 45),
#              ('만', 221),
#              ('원', 660),
#              ('지원기', 7),
#              ('간', 142),
#              ('최대', 41),
#              ('서', 551),
#              ('울', 131),
#              ('산업', 111),
#              ('진흥', 55),
#              ('메이드', 4),
#              ('란', 211),
#              ('서울', 548),
#              ('감성', 3),
#              ('담다', 23),
#              ('다양하다', 67),
#              ('새롭다', 29),
#              ('경험', 26),
#              ('제공', 174),
#              ('위해', 144),
#              ('만들어지다', 3),
#              ('라이프스타일', 1),
#              ('플랫폼', 3),
#              ('브랜드', 14),
#              ('로', 1181),
#              ('이', 2688),
#              ('만들다', 31),
#              ('세계', 14),
#              ('가', 1430),
#              ('함께', 93),
#              ('쓰다', 14),
#              ('이다', 734),
#              ('기업', 129),
#              ('협업', 10),
#              ('상품', 22),
#              ('발굴', 15),
#              ('사용', 360),
#              ('원하다', 45),
#              ('중소기업', 36),
#              ('에게', 299),
#              ('등', 1668),
#              ('관련', 535),
#              ('상세', 40),
#              ('문의사항', 16),
#              ('브랜드전략', 1),
#              ('팀', 189),
#              ('광진', 28),
#              ('맘', 48),
#              ('택시', 35),
#              ('운영', 638),
#              ('임산부', 14),
#              ('영아', 30),
#              ('전용', 77),
#              ('교통', 150),
#              ('약자', 11),
#              ('와', 613),
#              ('병원', 58),
#              ('진료', 98),
#              ('를', 2738),
#              ('받다', 665),
#              ('갈다', 22),
#              ('떄', 1),
#              ('쾌적하다', 16),
#              ('안전하다', 32),
#              ('이동', 29),
#              ('수', 1239),
#              ('대상자', 157),
#              ('광진구', 37),
#              ('이하', 235),
#              ('두다', 35),
#              ('해당', 432),
#              ('월', 614),
#              ('이전', 117),
#              ('출생', 6),
#              ('이용', 531),
#              ('가능', 303),
#              ('예', 95),
#              ('회원', 95),
#              ('가입', 140),
#              ('가정당', 1),
#              ('만원', 191),
#              ('이용권', 10),
#              ('시기', 78),
#              ('또는', 700),
#              ('건강', 131),
#              ('관리', 801),
#              ('목적', 143),
#              ('귀가', 7),
#              ('의원', 82),
#              ('한의원', 3),
#              ('약국', 25),
#              ('보건소', 46),
#              ('산후조리원', 1),
#              ('아기', 4),
#              ('프로그램', 179),
#              ('요가', 3),
#              ('마사지', 1),
#              ('진행', 105),
#              ('시설', 1129),
#              ('신청서', 180),
#              ('제출', 289),
#              ('후', 480),
#              ('앱', 25),
#              ('설치', 453),
#              ('증빙', 40),
#              ('자료', 176),
#              ('확인', 443),
#              ('이메일', 70),
#              ('부터는', 9),
#              ('으', 10),
#              ('다운로드', 61),
#              ('생애', 10),
#              ('주', 230),
#              ('기', 275),
#              ('여성', 103),
#              ('서비스', 319),
#              ('사', 298),
#              ('안드로이드', 2),
#              ('플레이스토어', 1),
#              ('아이폰', 2),
#              ('에서', 1209),
#              ('아이엠', 1),
#              ('검색', 88),
#              ('호출', 2),
#              ('본인', 133),
#              ('계정', 12),
#              ('내', 425),
#              ('쿠폰', 11),
#              ('결제', 69),
#              ('영수증', 13),
#              ('회차', 6),
#              ('부여', 32),
#              ('차', 166),
#              ('목', 62),
#              ('마포', 35),
#              ('뇌', 9),
#              ('병변', 7),
#              ('장애인', 188),
#              ('비다', 62),
#              ('구분', 219),
#              ('학령기', 1),
#              ('곳', 86),
#              ('없다', 415),
#              ('중증', 6),
#              ('교육', 608),
#              ('돌보다', 38),
#              ('맞춤', 41),
#              ('종합', 165),
#              ('만세', 20),
#              ('미만', 148),
#              ('중복', 32),
#              ('시간', 359),
#              ('평일', 110),
#              ('실', 187),
#              ('수업', 20),
#              ('료', 69),
#              ('식비', 6),
#              ('별도', 88),
#              ('기초', 64),
#              ('수급', 100),
#              ('무료', 133),
#              ('상위', 60),
#              ('계층', 48),
#              ('감다', 10),
#              ('개별', 67),
#              ('특성', 34),
#              ('욕구', 7),
#              ('기반', 19),
#              ('으로', 1686),
#              ('이용자', 19),
#              ('모집', 150),
#              ('유선', 27),
#              ('예약', 90),
#              ('방', 35),
#              ('하', 304),
#              ('접수', 306),
#              ('문', 144),
#              ('의처', 35),
#              ('마포구', 49),
#              ('신촌로', 1),
#              ('길', 131),
#              ('우리', 116),
#              ('복지관', 47),
#              ('층', 279),
#              ('기타', 253),
#              ('사항', 595),
#              ('문의', 323),
#              ('는', 1841),
#              ('년도', 61),
#              ('중고', 20),
#              ('신입생', 8),
#              ('입학', 21),
#              ('준비', 54),
#              ('서울시', 670),
#              ('전국', 36),
#              ('최초', 36),
#              ('개', 329),
#              ('자치구', 93),
#              ('교육청', 36),
#              ('협력', 43),
#              ('관내', 44),
#              ('국', 49),
#              ('공', 546),
#              ('사립', 6),
#              ('중', 541),
#              ('고', 248),
#              ('고등', 6),
#              ('기술', 285),
#              ('특수', 36),
#              ('각종', 71),
#              ('학교', 171),
#              ('학생', 44),
#              ('들', 290),
#              ('감소', 5),
#              ('소득', 140),
#              ('관계없이', 19),
#              ('교복', 25),
#              ('의류', 23),
#              ('스마트', 8),
#              ('기기', 19),
#              ('공공', 118),
#              ('강화', 39),
#              ('보편', 2),
#              ('실현', 17),
#              ('설명', 66),
#              ('방식', 50),
#              ('은', 2498),
#              ('각', 236),
#              ('학부모', 54),
#              ('구매', 38),
#              ('제로', 11),
#              ('페이', 5),
#              ('모바일', 12),
#              ('포인트', 18),
#              ('이며', 141),
#              ('구입', 45),
#              ('범위', 142),
#              ('복', 7),
#              ('체육복', 4),
#              ('일상', 32),
#              ('등교', 4),
#              ('필요하다', 238),
#              ('격', 9),
#              ('날짜', 20),
#              ('고등학교', 28),
#              ('태블릿', 1),
#              ('노트북', 2),
#              ('비고', 10),
#              ('학칙', 1),
#              ('정', 206),
#              ('한', 1620),
#              ('형태', 51),
#              ('추진', 208),
#              ('과제', 4),
#              ('용', 119),
#              ('등록', 356),
#              ('가맹', 16),
#              ('점', 75),
#              ('위', 504),
#              ('사업', 1236),
#              ('필수', 19),
#              ('물품', 80),
#              ('제한', 152),
#              ('전원', 22),
#              ('금액', 146),
#              ('예산', 111),
#              ('교부', 30),
#              ('주관', 23),
#              ('비', 354),
#              ('처리', 273),
#              ('외', 130),
#              ('매', 64),
#              ('물리다', 9),
#              ('입다', 9),
#              ('코드', 3),
#              ('간편', 1),
#              ('활용', 94),
#              ('중학생', 3),
#              ('세', 219),
#              ('불가', 65),
#              ('신고', 438),
#              ('수리', 13),
#              ('인가', 96),
#              ('대안교육', 1),
#              ('기관', 378),
#              ('밖', 31),
#              ('청소년', 263),
#              ('에도', 85),
#              ('공교육', 1),
#              ('같다', 140),
#              ('부모', 44),
#              ('씩', 25),
#              ('예정', 102),
#              ('위드유', 4),
#              ('직장', 39),
#              ('성희롱', 17),
#              ('성폭력', 20),
#              ('예방', 83),
#              ('체계', 44),
#              ('지대', 5),
#              ('시민', 211),
#              ('평등하다', 3),
#              ('민관', 6),
#              ('통해', 143),
#              ('피해자', 14),
#              ('소규모', 14),
#              ('장', 306),
#              ('형', 137),
#              ('개념', 12),
#              ('원인', 16),
#              ('이해', 24),
#              ('조직', 49),
#              ('평등', 5),
#              ('문화', 202),
#              ('점검', 85),
#              ('고충', 6),
#              ('사건', 8),
#              ('분쟁해결', 2),
#              ('절차', 182),
#              ('안내', 218),
#              ('작성', 133),
#              ('컨설팅', 46),
#              ('법률', 143),
#              ('전문가', 55),
#              ('매칭', 4),
#              ('진단', 40),
#              ('솔루션', 4),
#              ('내부', 25),
#              ('규정', 412),
#              ('개선', 121),
#              ('방안', 28),
#              ('제시', 29),
#              ('피해', 79),
#              ('지', 547),
#              ('연대', 6),
#              ('공백', 1),
#              ('종사', 36),
#              ('역량', 18),
#              ('동행', 3),
#              ('대응', 8),
#              ('워크숍', 7),
#              ('사례', 66),
#              ('연구', 36),
#              ('회', 299),
#              ('정책', 130),
#              ('네트워크', 12),
#              ('협의', 81),
#              ('정보화', 14),
#              ('확산', 15),
#              ('대', 274),
#              ('홍보', 77),
#              ('캠페인', 15),
#              ('여성폭력', 5),
#              ('상담', 342),
#              ('긴급', 21),
#              ('전화', 187),
#              ('아동', 107),
#              ('통합', 80),
#              ('폭력', 7),
#              ('이주', 14),
#              ('원스톱', 2),
#              ('성폭행', 3),
#              ('가정폭력', 21),
#              ('성매매', 14),
#              ('학교폭력', 4),
#              ('주의', 45),
#              ('특이', 4),
#              ('위치', 137),
#              ('중구', 71),
#              ('무교로', 3),
#              ('더', 36),
#              ('익스', 3),
#              ('체인지', 2),
#              ('빌딩', 59),
#              ('법규', 18),
#              ('서울특별시', 202),
#              ('방지', 81),
#              ('보호', 153),
#              ('관', 487),
#              ('조례', 101),
#              ('성동구', 38),
#              ('반려동물', 24),
#              ('상', 350),
#              ('무엇', 493),
#              ('이든', 2),
#              ('물어보다', 1),
#              ('월월', 26),
#              ('이용대', 17),
#              ('성동', 15),
#              ('구민', 46),
#              ('누구', 54),
#              ('나', 233),
#              ('취약', 14),
#              ('우선', 53),
#              ('배정', 50),
#              ('일정', 106),
#              ('첫째', 8),
#              ('셋째', 6),
#              ('금요일', 14),
#              ('사전예약', 11),
#              ('사전', 71),
#              ('상담시', 10),
#              ('분', 240),
#              ('조정', 55),
#              ('상태', 47),
#              ('행동', 18),
#              ('초기', 4),
#              ('교정', 9),
#              ('간단하다', 8),
#              ('육아', 55),
#              ('진찰', 1),
#              ('촉진', 82),
#              ('수의학', 1),
#              ('부분', 102),
#              ('문제해결', 3),
#              ('방향', 46),
#              ('대처', 6),
#              ('정밀검사', 1),
#              ('필요', 83),
#              ('여부', 176),
#              ('기존', 69),
#              ('잘못', 6),
#              ('알', 91),
#              ('의무', 135),
#              ('월령', 1),
#              ('개다', 39),
#              ('미등록', 3),
#              ('동물', 54),
#              ('장소', 135),
#              ('전문', 53),
#              ('우리동네', 17),
#              ('꼼꼼', 5),
#              ('책자', 24),
#              ('명의', 70),
#              ('반장', 7),
#              ('직접', 118),
#              ('발', 6),
#              ('뛰다', 3),
#              ('수집', 19),
#              ('지역', 517),
#              ('마다', 47),
#              ('종', 117),
#              ('총', 120),
#              ('발간', 35),
#              ('에는', 461),
#              ('소개', 57),
#              ('기별', 9),
#              ('담기다', 5),
#              ('출생신고', 1),
#              ('출산', 41),
#              ('전달', 39),
#              ('열리다', 47),
#              ('공동', 121),
#              ('나눔', 33),
#              ('터', 26),
#              ('아이', 58),
#              ('자주', 9),
#              ('찾다', 25),
#              ('배포', 14),
#              ('인터넷', 150),
#              ('포털', 25),
#              ('양', 109),
#              ('육', 31),
#              ('인가요', 347),
#              ('부문', 22),
#              ('역할', 34),
#              ('강화하다', 7),
#              ('설립', 114),
#              ('출연', 9),
#              ('공립', 26),
#              ('회복', 60),
#              ('재', 91),
#              ('민간', 66),
#              ('재무회계', 8),
#              ('노무', 19),
#              ('자세하다', 55),
#              ('참고', 53),
#              ('십', 6),
#              ('시오', 6),
#              ('주요', 122),
#              ('보기', 12),
#              ('대표', 115),
#              ('장기', 33),
#              ('요양', 29),
#              ('모두', 49),
#              ('타', 86),
#              ('보건복지부', 14),
#              ('운송', 12),
#              ('조합', 154),
#              ('거동', 2),
#              ('불편하다', 11),
#              ('어르신', 49),
#              ('도', 334),
#              ('비롯', 6),
#              ('외출', 1),
#              ('권', 132),
#              ('보장', 39),
#              ('시범', 19),
#              ('시행', 362),
#              ('코로나', 2),
#              ('지속', 23),
#              ('운영자', 6),
#              ('사유', 78),
#              ('일부', 58),
#              ('실제', 24),
#              ('거주', 96),
#              ('등급', 36),
#              ('않다', 324),
#              ('휠체어', 15),
#              ('탑승', 16),
#              ('유무', 14),
#              ('월토', 1),
#              ('공휴일', 51),
#              ('요금', 79),
#              ('한도', 41),
#              ('액', 75),
#              ('동안', 24),
#              ('본', 86),
#              ('인부', 9),
#              ('담그다', 9),
#              ('자유롭다', 23),
#              ('중형', 6),
#              ('추가', 55),
#              ('기본', 113),
#              ('거리', 119),
#              ('당', 115),
#              ('용지역', 1),
#              ('시내', 12),
#              ('에서만', 7),
#              ('시외', 2),
#              ('운행', 40),
#              ('공단', 92),
#              ('카드', 193),
#              ('발급', 235),
#              ('콜센터', 71),
#              ('통한', 46),
#              ('배차', 1),
#              ('차량', 84),
#              ('지다', 67),
#              ('차다', 52),
#              ('소재', 62),
#              ('가깝다', 17),
#              ('국민', 118),
#              ('보험', 123),
#              ('노인장', 5),
#              ('원칙', 73),
#              ('신체', 12),
#              ('인지', 65),
#              ('기능', 80),
#              ('저하', 6),
#              ('친족', 7),
#              ('대리', 27),
#              ('그', 339),
#              ('독거', 9),
#              ('이해관계', 7),
#              ('지사', 22),
#              ('영등포', 23),
#              ('북부', 9),
#              ('강남', 29),
#              ('동부', 15),
#              ('개인정보', 29),
#              ('제자', 7),
#              ('동의', 105),
#              ('신분증', 48),
#              ('관계', 106),
#              ('증명서', 123),
#              ('위임장', 14),
#              ('월말', 13),
#              ('소멸', 4),
#              ('이월', 9),
#              ('시점', 31),
#              ('말일', 2),
#              ('까지', 212),
#              ('잔액', 15),
#              ('보다', 113),
#              ('많다', 54),
#              ('초과', 73),
#              ('전액', 22),
#              ('담당', 197),
#              ('처', 55),
#              ('상이', 32),
#              ('제도', 137),
#              ('건', 33),
#              ('부당', 6),
#              ('승차', 5),
#              ('거부', 49),
#              ('여객', 19),
#              ('자동차', 92),
#              ('운수', 26),
#              ('법', 385),
#              ('불편', 46),
#              ('일반', 128),
#              ('동일하다', 37),
#              ('가구', 82),
#              ('성화', 4),
#              ('의료', 191),
#              ('유기', 4),
#              ('위험', 50),
#              ('줄', 5),
#              ('이고', 72),
#              ('방치', 8),
#              ('차단', 14),
#              ('서다', 78),
#              ('동물복지', 1),
#              ('중위', 2),
#              ('고양이', 5),
#              ('증명', 66),
#              ('중성', 9),
#              ('수술', 9),
#              ('전', 250),
#              ('단계', 34),
#              ('건강검진', 5),
#              ('실시', 175),
#              ('검진', 9),
#              ('결과', 109),
#              ('화가', 3),
#              ('못', 63),
#              ('수도', 23),
#              ('전체', 39),
#              ('소진', 1),
#              ('조기', 10),
#              ('마감', 23),
#              ('시작', 24),
#              ('설문지', 3),
#              ('지정', 200),
#              ('동물병원', 3),
#              ('집', 60),
#              ('오프라인', 10),
#              ('카라', 6),
#              ('출력', 9),
#              ('수기', 4),
#              ('동봉', 5),
#              ('우편', 56),
#              ('주소', 178),
#              ('잔', 15),
#              ('다리', 5),
#              ('담당자', 118),
#              ('앞', 65),
#              ('메', 1),
#              ('혹은', 12),
#              ('카카오', 3),
#              ('톡', 3),
#              ('플러스', 11),
#              ('친구', 21),
#              ('가장', 28),
#              ('빠르다', 8),
#              ('안내받다', 1),
#              ('동물권', 3),
#              ('대한', 298),
#              ('주시', 29),
#              ('면', 122),
#              ('아름답다', 12),
#              ('청년', 33),
#              ('전태일', 5),
#              ('기념관', 10),
#              ('종로구', 42),
#              ('청계천로', 8),
#              ('수동', 5),
#              ('용도', 134),
#              ('전시품', 1),
#              ('수장', 1),
#              ('로비', 1),
#              ('공연', 25),
#              ('장석', 1),
#              ('전시', 28),
#              ('체험', 102),
#              ('노동자', 7),
#              ('익', 4),
#              ('노동', 8),
#              ('허브', 13),
#              ('노동권', 1),
#              ('사무', 43),
#              ('휴게', 10),
#              ('공간', 121),
#              ('관람', 12),
#              ('입장', 14),
#              ('완료', 62),
#              ('휴', 40),
#              ('관일', 8),
#              ('매주', 47),
#              ('월요일', 14),
#              ('월일', 15),
#              ('설', 8),
#              ('추석', 13),
#              ('당일', 16),
#              ('휴무', 21),
#              ('상설', 3),
#              ('꿈', 25),
#              ('그리고', 18),
#              ('기획', 83),
#              ('모범', 11),
#              ('업체', 102),
#              ('태일', 1),
#              ('피복', 2),
#              ('이외', 34),
#              ('일수', 44),
#              ('개관', 13),
#              ('식', 82),
#              ('정식', 7),
#              ('일화', 25),
#              ('재단', 38),
#              ('법인', 128),
#              ('지점', 44),
#              ('이나', 177),
#              ('소', 264),
#              ('시공', 42),
#              ('가능하다', 436),
#              ('건설', 323),
#              ('에서는', 142),
#              ('건설업', 22),
#              ('영업', 111),
#              ('구역', 268),
#              ('대하', 150),
#              ('아니다', 330),
#              ('허용', 43),
#              ('따라서', 40),
#              ('업종', 26),
#              ('것', 541),
#              ('백서', 10),
#              ('몇', 82),
#              ('주기', 31),
#              ('지난', 12),
#              ('추다', 64),
#              ('최근', 30),
#              ('기후', 4),
#              ('본부', 48),
#              ('기후변화', 2),
#              ('권선', 1),
#              ('조', 333),
#              ('주무관', 10),
#              ('개인', 148),
#              ('시청', 97),
#              ('정도', 47),
#              ('공원', 101),
#              ('상수도', 1),
#              ('코너', 13),
#              ('비영리', 17),
#              ('제조', 415),
#              ('제', 812),
#              ('항의', 41),
#              ('의거', 76),
#              ('국가', 92),
#              ('지자체', 16),
#              ('자본금', 79),
#              ('출자', 12),
#              ('영리', 37),
#              ('다른', 120),
#              ('특별하다', 15),
#              ('제외', 163),
#              ('하고는', 4),
#              ('동조', 1),
#              ('의하다', 395),
#              ('주유소', 15),
#              ('석유', 30),
#              ('판매업', 13),
#              ('이란', 308),
#              ('뭔', 15),
#              ('가요', 40),
#              ('뭔가', 3),
#              ('요란', 1),
#              ('에너지', 85),
#              ('절약', 34),
#              ('사용자', 37),
#              ('노후', 19),
#              ('저', 85),
#              ('효율', 74),
#              ('운전', 46),
#              ('개체', 4),
#              ('보완', 16),
#              ('때', 140),
#              ('가다', 90),
#              ('효과', 31),
#              ('보증', 121),
#              ('수행', 92),
#              ('어떻다', 595),
#              ('산', 36),
#              ('건물', 113),
#              ('소형', 9),
#              ('열', 26),
#              ('병합', 7),
#              ('발전', 55),
#              ('보일러', 23),
#              ('교체', 12),
#              ('전기', 20),
#              ('대체', 9),
#              ('냉방', 1),
#              ('수요', 8),
#              ('투자', 55),
#              ('공정', 18),
#              ('폐', 14),
#              ('회수', 7),
#              ('장점', 9),
#              ('없이', 94),
#              ('늘다', 38),
#              ('수익', 12),
#              ('보고', 47),
#              ('베다', 3),
#              ('처형', 2),
#              ('으로는', 18),
#              ('투', 7),
#              ('자비', 2),
#              ('비용', 121),
#              ('절감', 11),
#              ('위험부담', 2),
#              ('해소', 15),
#              ('으로부터', 50),
#              ('자금지원', 7),
#              ('세제', 2),
#              ('혜택', 19),
#              ('은평', 50),
#              ('꽃', 29),
#              ('피다', 8),
#              ('장날', 6),
#              ('출전', 5),
#              ('총회', 41),
#              ('둘째', 17),
#              ('토요일', 46),
#              ('장터', 30),
#              ('중후', 1),
#              ('반', 154),
#              ('주간', 22),
#              ('농부', 10),
#              ('인근', 13),
#              ('농사', 4),
#              ('짓다', 6),
#              ('도시', 467),
#              ('소농', 1),
#              ('경기도', 11),
#              ('요리', 19),
#              ('건강하다', 20),
#              ('레시피', 6),
#              ('먹거리', 9),
#              ('유기농', 5),
#              ('친환경', 67),
#              ('농작물', 9),
#              ('권장', 12),
#              ('경', 117),
#              ('단체', 243),
#              ('고려', 35),
#              ('공예품', 2),
#              ('제작', 41),
#              ('은평구', 92),
#              ('공지', 48),
#              ('참여', 200),
#              ('확정', 44),
#              ('점비', 1),
#              ('납부', 98),
#              ('롯데', 13),
#              ('몰다', 3),
#              ('평점', 2),
#              ('광장', 60),
#              ('호선', 88),
#              ('구파발역', 3),
#              ('번', 143),
#              ('출구', 93),
#              ('대중교통', 14),
#              ('부스', 7),
#              ('파라솔', 2),
#              ('테이블', 2),
#              ('의자', 11),
#              ('우천', 5),
#              ('변경', 401),
#              ('취소', 81),
#              ('오전', 26),
#              ('현장', 111),
#              ('즐기다', 8),
#              ('명아주', 1),
#              ('지팡이', 5),
#              ('블루베리', 1),
#              ('사과', 6),
#              ('식초', 1),
#              ('포도', 1),
#              ('고추', 2),
#              ('옥수수', 2),
#              ('복숭아', 1),
#              ('고사리', 1),
#              ('텃밭', 23),
#              ('김치', 4),
#              ('송이버섯', 1),
#              ('노루', 1),
#              ('궁뎅', 1),
#              ('버섯', 7),
#              ('매회', 4),
#              ('두부', 5),
#              ('채소', 14),
#              ('깻잎', 1),
#              ('호박', 1),
#              ('즉석', 3),
#              ('겉절이', 1),
#              ('장류', 2),
#              ('천', 50),
#              ('연', 239),
#              ('발효종', 1),
#              ('빵', 1),
#              ('발효식품', 1),
#              ('공정무역', 2),
#              ('커피', 12),
#              ('식혜', 1),
#              ...])

# %%
total_cnt = len(tokenizer.word_index)
total_cnt
# Out:
# 11519

# %%
# 사용 단어 수를 지정하여 토큰화 : num_words = 1000
num_words = 1000
tokenizer = Tokenizer(num_words = num_words)
tokenizer.fit_on_texts(df["token"])

# %%
df["token"] = tokenizer.texts_to_sequences(df["token"])

# %%
df.head()
# Out:
#    분류                                                 문서  \
# 0  복지  아빠 육아휴직 장려금아빠 육아휴직 장려금   업무개요  남성근로자의 육아휴직을 장려...
# 1  경제  서울산업진흥원 서울메이드란서울산업진흥원 서울메이드란 서울의 감성을 담은 다양하고 새...
# 2  복지  광진맘택시 운영임산부영아 양육가정 전용 택시광진맘택시 운영임산부영아 양육가정 전용 ...
# 3  복지  마포 뇌병변장애인 비전센터마포 뇌병변장애인 비전센터 마포뇌병변장애인 비전센터 운영 ...
# 4  행정  년도 중고 신입생 입학준비금 지원년도 중고 신입생 입학준비금 지원  업무개요  서울...
#
#                                                token
# 0  [422, 422, 51, 218, 838, 2, 4, 39, 3, 67, 482,...
# 1  [53, 283, 337, 658, 43, 53, 283, 175, 54, 337,...
# 2  [734, 973, 44, 358, 493, 973, 734, 973, 44, 35...
# 3  [975, 196, 590, 37, 975, 196, 590, 37, 975, 19...
# 4  [602, 675, 422, 31, 602, 675, 422, 31, 51, 218...

# %% [markdown]
# ### 길이 확인

# %%
length = [len(i) for i in df["token"].tolist()]

# %%
# 길이 평균값과 중간값
print(np.mean(length), np.median(length), np.min(length), np.max(length))
# Out:
# 84.84043051006083 55.0 2 2913

# %% [markdown]
# ### 데이터 분할

# %%
x = df["token"]
y = df["분류"]

# %%
labels = {0 : "행정", 1 : "경제", 2 : "복지"}
labels_rev = {"행정" : 0, "경제" : 1, "복지" : 2}

# %%
y = y.map(labels_rev)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, stratify = y, random_state = 7)

# %%
x_sub, x_val, y_sub, y_val = train_test_split(x_train, y_train, test_size = 0.2, stratify = y_train, random_state = 7)

# %%
maxlen = 60

sub_seq = pad_sequences(x_sub, maxlen = maxlen, truncating = "pre")
val_seq = pad_sequences(x_val, maxlen = maxlen, truncating = "pre")
test_seq = pad_sequences(x_test, maxlen = maxlen, truncating = "pre")

# %%
y_oh_sub = keras.utils.to_categorical(y_sub)
y_oh_val = keras.utils.to_categorical(y_val)
y_oh_test = keras.utils.to_categorical(y_test)

# %% [markdown]
# ### 모델 구성 및 훈련

# %%
model = keras.Sequential([
    keras.layers.Embedding(num_words, 128, input_shape = (maxlen,)),
    keras.layers.Dropout(0.3),
    keras.layers.Conv1D(128, 5, activation = "relu"),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool1D(4),
    keras.layers.LSTM(64, dropout = 0.5, return_sequences = True),
    keras.layers.LSTM(64, dropout = 0.5),
    keras.layers.Dense(3, activation = "softmax")
])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\keras\src\layers\core\embedding.py:81: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ (None, 60, 128)             │         128,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 60, 128)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d (Conv1D)                      │ (None, 56, 128)             │          82,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 56, 128)             │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d (MaxPooling1D)         │ (None, 14, 128)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 14, 64)              │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 64)                  │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 3)                   │             195 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 293,187 (1.12 MB)
#  Trainable params: 292,931 (1.12 MB)
#  Non-trainable params: 256 (1.00 KB)

# %%
rmsprop = keras.optimizers.RMSprop(learning_rate = 5e-4)
model.compile(loss = "categorical_crossentropy", optimizer = rmsprop, metrics = ["accuracy"])
early_stopping_cb = keras.callbacks.EarlyStopping(patience = 4, restore_best_weights = True)

# %%
history = model.fit(sub_seq, y_oh_sub, batch_size = 16, epochs = 100,
                   validation_data = (val_seq, y_oh_val),
                   callbacks = [early_stopping_cb])
# Out:
# Epoch 1/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.4927 - loss: 0.9763 - val_accuracy: 0.6082 - val_loss: 0.9715
# Epoch 2/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5870 - loss: 0.8598 - val_accuracy: 0.6959 - val_loss: 0.8895
# Epoch 3/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7398 - loss: 0.6686 - val_accuracy: 0.7602 - val_loss: 0.7347
# Epoch 4/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7905 - loss: 0.5309 - val_accuracy: 0.7398 - val_loss: 0.6181
# Epoch 5/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8618 - loss: 0.3883 - val_accuracy: 0.7544 - val_loss: 0.5892
# Epoch 6/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8753 - loss: 0.3483 - val_accuracy: 0.7632 - val_loss: 0.6294
# Epoch 7/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9032 - loss: 0.2840 - val_accuracy: 0.7515 - val_loss: 0.7510
# Epoch 8/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9122 - loss: 0.2250 - val_accuracy: 0.7573 - val_loss: 0.7557
# Epoch 9/100
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9449 - loss: 0.1962 - val_accuracy: 0.7690 - val_loss: 0.8403

# %%
model.evaluate(test_seq, y_oh_test)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7888 - loss: 0.5749
# [0.6088308691978455, 0.7686915993690491]

# %% [markdown]
# ### 정확도 구하기

# %%
pred = model.predict(test_seq)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
accuracy = sum([int(np.argmax(pred[i]) == y_test.iloc[i]) for i in range(len(pred))]) / len(pred)

# %%
# 정확도 출력
print(accuracy)
# Out:
# 0.7686915887850467

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %% [markdown]
# ### 독립변수 읽기

# %%
# 각 기상 데이터 읽기
kr_df = pd.read_csv(r".\Git\데이터\3. 예측데이터\korea_weather.csv", index_col = 0, header = [0, 1])
cn_df = pd.read_csv("./cn_weather.csv", index_col = 0, header = [0, 1])
sea_df = pd.read_csv(r".\Git\데이터\3. 예측데이터\sea_weather.csv", index_col = 0, header = [0, 1])
mg_df = pd.read_csv(r".\Git\데이터\3. 예측데이터\mongol_data.csv")
cn_dust = pd.read_csv(r".\Git\데이터\3. 예측데이터\6월중국미세먼지데이터.csv", index_col = 0)

# %%
kr_df.columns = kr_df.columns.map(lambda x: str(x))
cn_df.columns = cn_df.columns.map(lambda x: str(x))
sea_df.columns = sea_df.columns.map(lambda x: str(x))
cn_dust.columns = cn_dust.columns.map(lambda x: str(x))

# %%
pm10 = pd.read_csv("./pm10_final_v1.csv", index_col = 0)

# %%
kr_columns = pm10.columns[5:860]
cn_columns = pm10.columns[860:1696]
sea_columns = pm10.columns[1696:2149]
mg_columns = pm10.columns[2149:2191]
cn_dust_columns = pm10.columns[2191:2205]
date_columns = pm10.columns[2205:]

# %%
for column in kr_columns[~kr_columns.isin(kr_df.columns)]:
    kr_df[column] = False
# Out:
# C:\Users\sangi\AppData\Local\Temp\ipykernel_9860\349999173.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_df[column] = False
# C:\Users\sangi\AppData\Local\Temp\ipykernel_9860\349999173.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_df[column] = False
# ...

# %%
kr_df = kr_df.loc[:, kr_columns]

# %%
sum(kr_df.columns != kr_columns)
# Out:
# 0

# %%
kr_df.to_csv("./kr_predict_data.csv")

# %%
cn_df.columns
# Out:
# Index(['('습도', '50745.0')', '('습도', '51463.0')', '('습도', '52203.0')',
#        '('습도', '52681.0')', '('습도', '52983.0')', '('습도', '53614.0')',
#        '('습도', '53845.0')', '('습도', '54026.0')', '('습도', '54511.0')',
#        '('습도', '54823.0')',
#        ...
#        '('풍향', '59287.0_140.0')', '('풍향', '59287.0_160.0')',
#        '('풍향', '59287.0_180.0')', '('풍향', '59287.0_200.0')',
#        '('풍향', '59287.0_220.0')', '('풍향', '59287.0_260.0')',
#        '('풍향', '59287.0_280.0')', '('풍향', '59287.0_300.0')',
#        '('풍향', '59287.0_320.0')', '('풍향', '59287.0_340.0')'],
#       dtype='object', length=468)

# %%
cn_columns[~cn_columns.isin(cn_df.columns)]
# Out:
# Index(['('풍향', '50745.0_10.0')', '('풍향', '50745.0_30.0')',
#        '('풍향', '50745.0_50.0')', '('풍향', '50745.0_70.0')',
#        '('풍향', '50745.0_90.0')', '('풍향', '50745.0_110.0')',
#        '('풍향', '50745.0_130.0')', '('풍향', '50745.0_150.0')',
#        '('풍향', '50745.0_170.0')', '('풍향', '50745.0_180.0')',
#        ...
#        '('풍향', '59287.0_190.0')', '('풍향', '59287.0_210.0')',
#        '('풍향', '59287.0_230.0')', '('풍향', '59287.0_240.0')',
#        '('풍향', '59287.0_250.0')', '('풍향', '59287.0_270.0')',
#        '('풍향', '59287.0_290.0')', '('풍향', '59287.0_310.0')',
#        '('풍향', '59287.0_330.0')', '('풍향', '59287.0_350.0')'],
#       dtype='object', length=368)

# %%
for column in cn_columns[~cn_columns.isin(cn_df.columns)]:
    cn_df[column] = False
# Out:
# C:\Users\sangi\AppData\Local\Temp\ipykernel_9860\3034364804.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cn_df[column] = False
# C:\Users\sangi\AppData\Local\Temp\ipykernel_9860\3034364804.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   cn_df[column] = False
# ...

# %%
cn_df = cn_df.loc[:, cn_columns]

# %%
sum(cn_df.columns != cn_columns)
# Out:
# 0

# %%
cn_df.to_csv("./cn_predict_data.csv")

# %%
sea_columns[~sea_columns.isin(sea_df.columns)]
# Out:
# Index(['('풍향', "('21229', 0.0)")', '('풍향', "('21229', 10.0)")',
#        '('풍향', "('21229', 20.0)")', '('풍향', "('21229', 30.0)")',
#        '('풍향', "('21229', 40.0)")', '('풍향', "('21229', 50.0)")',
#        '('풍향', "('21229', 60.0)")', '('풍향', "('21229', 70.0)")',
#        '('풍향', "('21229', 80.0)")', '('풍향', "('21229', 90.0)")',
#        ...
#        '('풍향', "('22184', 230.0)")', '('풍향', "('22184', 240.0)")',
#        '('풍향', "('22184', 260.0)")', '('풍향', "('22184', 270.0)")',
#        '('풍향', "('22184', 300.0)")', '('풍향', "('22184', 320.0)")',
#        '('풍향', "('22184', 330.0)")', '('풍향', "('22184', 350.0)")', '습도', '풍속'],
#       dtype='object', length=199)

# %%
for column in sea_columns[~sea_columns.isin(sea_df.columns)]:
    sea_df[column] = False
# Out:
# C:\Users\sangi\AppData\Local\Temp\ipykernel_9860\1763441894.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   sea_df[column] = False
# C:\Users\sangi\AppData\Local\Temp\ipykernel_9860\1763441894.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   sea_df[column] = False
# ...

# %%
sea_df = sea_df.loc[:, sea_columns]

# %%
sum(sea_df.columns != sea_columns)
# Out:
# 0

# %%
sea_df.to_csv("./sea_predict_data.csv")

# %%
mg_df = mg_df.iloc[:, 2:].set_index("일시")

# %%
mg_df.columns = ['습도', '풍속', '풍향', '강수량', '현지기압', '해면기압', '변화량 기압', '이슬점 온도',
       '기온']

# %%
mg_df = pd.concat([mg_df, pd.get_dummies(mg_df["풍향"])], axis = 1)

# %%
mg_df = mg_df.drop("풍향", axis = 1)

# %%
mg_df.columns = mg_df.columns.map(lambda x: str(x))

# %%
for column in mg_columns[~mg_columns.isin(mg_df.columns)]:
    mg_df[column] = False

# %%
mg_df = mg_df.loc[:, mg_columns]

# %%
sum(mg_df.columns != mg_columns)
# Out:
# 0

# %%
mg_df.to_csv("./mg_predict_data.csv")

# %%
cn_dust = cn_dust.loc[:, ['베이징(PM25)', '광저우(PM25)', '난징(PM25)', '칭따오(PM25)', '상하이(PM25)',
       '우루무치(PM25)', '우한(PM25)', '베이징(PM10)', '광저우(PM10)', '난징(PM10)',
       '칭따오(PM10)', '상하이(PM10)', '우루무치(PM10)', '우한(PM10)'] ]

# %%
cn_dust.columns = cn_dust_columns

# %%
cn_dust.to_csv("./cn_dust_predict_data.csv")

# %%
final_df = pd.concat([kr_df, cn_df, sea_df, mg_df], axis = 1)

# %%
final_df.index
# Out:
# Index(['2024-06-05 00:00:00', '2024-06-05 03:00:00', '2024-06-05 06:00:00',
#        '2024-06-05 09:00:00', '2024-06-05 12:00:00', '2024-06-05 15:00:00',
#        '2024-06-05 18:00:00', '2024-06-05 21:00:00', '2024-06-06 00:00:00',
#        '2024-06-06 03:00:00', '2024-06-06 06:00:00', '2024-06-06 09:00:00',
#        '2024-06-06 12:00:00', '2024-06-06 15:00:00', '2024-06-06 18:00:00',
#        '2024-06-06 21:00:00', '2024-06-07 00:00:00', '2024-06-07 03:00:00',
#        '2024-06-07 06:00:00', '2024-06-07 09:00:00', '2024-06-07 12:00:00',
#        '2024-06-07 15:00:00', '2024-06-07 18:00:00', '2024-06-07 21:00:00',
#        '2024-06-08 00:00:00', '2024-06-08 03:00:00', '2024-06-08 06:00:00',
#        '2024-06-08 09:00:00', '2024-06-08 12:00:00', '2024-06-08 15:00:00',
#        '2024-06-08 18:00:00', '2024-06-08 21:00:00', '2024-06-09 00:00:00',
#        '2024-06-09 03:00:00', '2024-06-09 06:00:00', '2024-06-09 09:00:00',
# ...

# %%
final_df.index = final_df.index.map(lambda x: datetime.strptime(x, "%Y-%m-%d %H:%M:%S"))

# %%
for column in cn_dust.columns:
    final_df[column] = np.nan
# Out:
# C:\Users\sangi\AppData\Local\Temp\ipykernel_9860\2789107469.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_df[column] = np.nan
# C:\Users\sangi\AppData\Local\Temp\ipykernel_9860\2789107469.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   final_df[column] = np.nan
# ...

# %%
# 각 날짜별로 미세먼지 농도 값 입력
for i in range(len(final_df)):
    # 미세먼지 데이터 특정을 위한 날짜값
    date = final_df.index.date[i]
    # concat_df에 입력할 위치를 특정하기 위한 datetime값
    datetime = final_df.index[i]
    # 데이터 특정, 입력 위치 특정을 위한 컬럼명 목록
    column = cn_dust.columns
    # 데이터 입력
    final_df.loc[datetime, column] = cn_dust.loc[str(date), :]

# %%
date_columns
# Out:
# Index(['month_1', 'month_2', 'month_3', 'month_4', 'month_5', 'month_6',
#        'month_7', 'month_8', 'month_9', 'month_10', 'month_11', 'month_12',
#        'hour_0', 'hour_3', 'hour_6', 'hour_9', 'hour_12', 'hour_15', 'hour_18',
#        'hour_21'],
#       dtype='object')

# %%
# 월 / 시간 값을 범주화한 데이터프레임 생성
datetime_df = pd.concat([pd.get_dummies(final_df.index.month, prefix = "month"), 
                         pd.get_dummies(final_df.index.hour, prefix = "hour")], axis = 1)

# %%
for column in date_columns[~date_columns.isin(datetime_df.columns)]:
    datetime_df[column] = False

# %%
date_columns
# Out:
# Index(['month_1', 'month_2', 'month_3', 'month_4', 'month_5', 'month_6',
#        'month_7', 'month_8', 'month_9', 'month_10', 'month_11', 'month_12',
#        'hour_0', 'hour_3', 'hour_6', 'hour_9', 'hour_12', 'hour_15', 'hour_18',
#        'hour_21'],
#       dtype='object')

# %%
datetime_df = datetime_df.loc[:, date_columns]

# %%
datetime_df.index = final_df.index

# %%
final_df = pd.concat([final_df, datetime_df], axis = 1)

# %%
final_df
# Out:
#                      ('강수량', '90')  ('강수량', '101')  ('강수량', '102')  \
# 일시
# 2024-06-05 00:00:00            0.0             0.0             0.0
# 2024-06-05 03:00:00            0.0             0.0             0.0
# 2024-06-05 06:00:00            0.0             0.0             0.0
# 2024-06-05 09:00:00            0.0             0.0             0.0
# 2024-06-05 12:00:00            0.0             0.0             0.0
# 2024-06-05 15:00:00            0.0             0.0             0.0
# 2024-06-05 18:00:00            0.0             0.0             0.0
# 2024-06-05 21:00:00            0.0             0.0             0.0
# 2024-06-06 00:00:00            0.0             0.0             0.0
# 2024-06-06 03:00:00            0.0             0.0             0.0
# 2024-06-06 06:00:00            0.0             0.0             0.0
# 2024-06-06 09:00:00            0.0             0.0             0.0
# 2024-06-06 12:00:00            0.0             0.0             0.0
# ...

# %%
sum(final_df.columns == pm10.columns[5:])
# Out:
# 2220

# %%
final_df.to_csv("./predict_data_v1.csv")
